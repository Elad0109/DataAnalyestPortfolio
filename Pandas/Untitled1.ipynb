# %%
import pandas as pd
import seaborn as sb

# %%
#1
airline = pd.read_csv("data/airlines.csv")

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 1 to 100
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CHOPER   100 non-null    object
#  1   CHOPERD  100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %%
x=range(1,101,1)

# %%
x
# Out:
# range(1, 101)

# %%
index= pd.Index(range(1,101,1))
airline.set_index(index,inplace=True)

# %%
airline
# Out:
#     CHOPER                   CHOPERD
# 1       PC          PEGASUS AIRLINES
# 2       LY     EL AL ISRAEL AIRLINES
# 3       TK          TURKISH AIRLINES
# 4       LX     SWISS INT`L  AIRLINES
# 5       FB             BULGARIA  AIR
# ..     ...                       ...
# 96      MJ            MYWAY AIRLINES
# 97     VJT             vista jet air
# 98     ENT                 ENTER AIR
# 99     BUC      EUROPEAN AIR CHARTER
# 100     RU  AIRBRIDGE CARGO AIRLINES
#
# [100 rows x 2 columns]

# %%
bs = pd.read_csv('data/bestsellers.csv')

# %%
bs.Author.value_counts().to_frame()
# Out:
#                                     count
# Author
# Jeff Kinney                            12
# Gary Chapman                           11
# Rick Riordan                           11
# Suzanne Collins                        11
# American Psychological Association     10
# ...                                   ...
# Keith Richards                          1
# Chris Cleave                            1
# Alice Schertle                          1
# Celeste Ng                              1
# Adam Gasiewski                          1
#
# [248 rows x 1 columns]

# %%
bs.Author.value_counts().iloc[0:5].to_frame()
# Out:
#                                     count
# Author
# Jeff Kinney                            12
# Gary Chapman                           11
# Rick Riordan                           11
# Suzanne Collins                        11
# American Psychological Association     10

# %%
bs.Author.value_counts().head().to_frame()
# Out:
#                                     count
# Author
# Jeff Kinney                            12
# Gary Chapman                           11
# Rick Riordan                           11
# Suzanne Collins                        11
# American Psychological Association     10

# %%
bs.Author.value_counts().to_frame().head()
# Out:
#                                     count
# Author
# Jeff Kinney                            12
# Gary Chapman                           11
# Rick Riordan                           11
# Suzanne Collins                        11
# American Psychological Association     10

# %%
titanic = sb.load_dataset("titanic")

# %%
emb=titanic['embarked'].isin(['C','Q'])
age =titanic['age'].between(30,50)
titanic[emb&age]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class
# 1           1       1  female  38.0      1      0   71.2833        C   First  \
# 30          0       1    male  40.0      0      0   27.7208        C   First
# 52          1       1  female  49.0      1      0   76.7292        C   First
# 122         0       2    male  32.5      1      0   30.0708        C  Second
# 130         0       3    male  33.0      0      0    7.8958        C   Third
# 177         0       1  female  50.0      0      0   28.7125        C   First
# 188         0       3    male  40.0      1      1   15.5000        Q   Third
# 194         1       1  female  44.0      0      0   27.7208        C   First
# 203         0       3    male  45.5      0      0    7.2250        C   Third
# 209         1       1    male  40.0      0      0   31.0000        C   First
# 215         1       1  female  31.0      1      0  113.2750        C   First
# ...

# %%
len(titanic[emb&age])
# Out:
# 58

# %%
len(titanic[emb&age])
# Out:
# 58

# %%
counter=0
name= input('enter a name')
grade=int(input('enter number'))
print(name)
print(grade)
for i in  range(3):
    if grade >95:
        counter +=1
        print(name)
    name= input('enter a name')
    grade=int(input('enter number'))
print (counter)
# Out:
# enter a namea
# enter number96
# a
# 96
# a
# enter a nameb
# enter number80
# enter a namec
# enter number100
# c
# enter a named
# enter number98
# 2

# %%
counter=0
num=0
name= input('enter a name')
grade=int(input('enter number'))
print(name)
print(grade)
while num <=3:
    if grade >95:
        counter +=1
        print(name)
    name= input('enter a name')
    grade=int(input('enter number'))
    num +=1
print (counter)

# %%
emp=pd.read_table("data/employee.txt")

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BusinessEntityID  290 non-null    int64
#  1   FirstName         290 non-null    object
#  2   LastName          290 non-null    object
#  3   HireDate          290 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 9.2+ KB

# %%
import datetime as dt

# %%
emp
# Out:
#      BusinessEntityID FirstName           LastName   HireDate
# 0                 172      Marc              Ingle 2009-01-16
# 1                 173    Eugene        Zabokritski 2009-01-21
# 2                 174  Benjamin             Martin 2009-01-27
# 3                 175      Reed               Koch 2009-02-02
# 4                 176     David           Lawrence 2009-02-14
# ..                ...       ...                ...        ...
# 285               286      Lynn           Tsoflias 2013-05-30
# 286               287       Amy            Alberts 2012-04-16
# 287               288    Rachel             Valdez 2013-05-30
# 288               289       Jae                Pak 2012-05-30
# 289               290    Ranjit  Varkey Chudukatil 2012-05-30
#
# [290 rows x 4 columns]

# %%
emp["HireDate"]=pd.to_datetime(emp["HireDate"],'%Y-%m-%d')

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BusinessEntityID  290 non-null    int64
#  1   FirstName         290 non-null    object
#  2   LastName          290 non-null    object
#  3   HireDate          290 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 9.2+ KB

# %%
((pd.Timestamp.today()-emp["HireDate"]).dt.days/365).round(1)
# Out:
# 0      14.4
# 1      14.4
# 2      14.4
# 3      14.4
# 4      14.3
#        ...
# 285    10.0
# 286    11.2
# 287    10.0
# 288    11.0
# 289    11.0
# Name: HireDate, Length: 290, dtype: float64

# %%
titanic=sb.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
mask=titanic["embarked"]=="No"

# %%
titanic["embarked"]=titanic["embarked"].fillna("No")

# %%
titanic["embarked"].replace("No","No information",inplace=True)

# %%
titanic["embarked"]=titanic["embarked"].str.replace("No information","No")

# %%
titanic[mask]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class
# 61          1       1  female  38.0      0      0  80.0       No  First  \
# 829         1       1  female  62.0      0      0  80.0       No  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
titanic["embarked"]=titanic["embarked"].replace("No information","No")

# %%
titanic["embarked"]=1

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  embarked   class
# 0           0       3    male  22.0      1      0   7.2500         1   Third  \
# 1           1       1  female  38.0      1      0  71.2833         1   First
# 2           1       3  female  26.0      0      0   7.9250         1   Third
# 3           1       1  female  35.0      1      0  53.1000         1   First
# 4           0       3    male  35.0      0      0   8.0500         1   Third
# ..        ...     ...     ...   ...    ...    ...      ...       ...     ...
# 886         0       2    male  27.0      0      0  13.0000         1  Second
# 887         1       1  female  19.0      0      0  30.0000         1   First
# 888         0       3  female   NaN      1      2  23.4500         1   Third
# 889         1       1    male  26.0      0      0  30.0000         1   First
# 890         0       3    male  32.0      0      0   7.7500         1   Third
#
# ...
