# %%
#https://matplotlib.org/stable/api/index.html

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb
# %matplotlib inline

# %%
Countries = pd.read_csv('data/Countries.csv')
pup=pd.read_csv('data/pupils.csv')
titanic=sb.load_dataset('titanic')

# %% [markdown]
# # Basic Matplotlib.pyplot graphs

# %%
plt.plot()
# Out:
# []

# %%
plt.plot([10,20,15,7])

# %%
x = [1, 3, 5, 7]
y = [50, 60, 45, 55]

# %%
#By default, the plot() function draws a line from point to point.
#plot(x, y)        # plot x and y using default line style and color
#plot(y)           # plot y using x as index array 0..N-1
plt.plot(x,y)

# %%
#Return ValueError: x and y must have same first dimension, but have shapes (4,) and (3,)
x = [1, 3, 5, 7]
y = [50, 60, 70]
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       2 x = [1, 3, 5, 7]
#       3 y = [50, 60, 70]
# ----> 4 plt.plot(x,y)
#
# File C:\Python311\Lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File C:\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
# ...

# %%
#arange()-Return evenly spaced values within a given interval.
print(np.arange(5))
# Out:
# [0 1 2 3 4]

# %%
y=np.arange(5)

# %%
y
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.plot(y)

# %%
#plt.show -Display all open figures
#Auto-show in jupyter notebooks

plt.plot(y)
plt.show()

# %%
y1=np.arange(5)
y2=y1*3
y3=y1**2

# %%
print(y1)
print(y2)
print(y3)
# Out:
# [0 1 2 3 4]
# [ 0  3  6  9 12]
# [ 0  1  4  9 16]

# %%
plt.plot(y1)
plt.plot(y2)
plt.plot(y3)
plt.show()

# %%
plt.plot(y1)
plt.show()
plt.plot(y2)
plt.show()
plt.plot(y3)
plt.show()

# %% [markdown]
# ### Figure

# %%
# figure -Create a new figure, or activate an existing figure.
plt.figure()
plt.plot(y1)
plt.figure()
plt.plot(y2)
plt.show()

# %% [markdown]
# ### Figure size

# %%
#figsize -Width, height in inches.
plt.figure(figsize=(5,4))
plt.plot(y1)
plt.show()

# %%
#dpi - The resolution of the figure in dots-per-inch.
plt.figure(figsize=(5,4),dpi=50)
plt.plot(y1)
plt.show()

# %% [markdown]
# # Format marker , line & color

# %%
#style|marker|line|color

# %% [markdown]
# ### Styles

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8')

# %%
plt.figure(figsize=(6,4),dpi=60)
plt.plot(y1)
plt.plot(y2)
plt.show()

# %% [markdown]
# # Color

# %%
#'k' - Black
#'w' - White
#'r' - Red
#'b' - Blue
#'g' - Green
#'c'-  Cyan
#'y' - Yellow
#https://coolors.co/palettes/trending

# %%
plt.figure(figsize=(5,4),dpi=60)
plt.plot(y1,color='b')
plt.plot(y2,color='#ffd60a')
plt.show()

# %%
plt.figure(figsize=(5,4),dpi=60)
plt.plot(y1,'b')
plt.plot(y2,'r')
plt.show()

# %% [markdown]
# # marker

# %%
#'o' - Circle--#parameter 'o', which means 'rings'.
#'*' - Star
#'.' - Point

# %%
plt.figure(figsize=(5,4),dpi=100)
plt.plot(y1,color='b',marker='*')
plt.plot(y2,color='#F94C66',marker='<')
plt.show()

# %% [markdown]
# # Line

# %%
#'-' - Solid line
#':' - Dotted line
#'--' - Dashed line

# %%
plt.figure(figsize=(5,4),dpi=100)
plt.plot(y1,color='b',linewidth=4,linestyle = 'dotted')
plt.plot(y2,color='#F94C66',linewidth=3,linestyle = '--')
plt.show()

# %% [markdown]
# # Marker size - ms

# %%
x = [1, 3, 5, 7,9]
y1=np.arange(5)
plt.plot(x,y1,marker =">",ms=10)

# %%
#line style
plt.plot(x,y,marker ='o',linestyle = 'dotted' , ms=10)

# %%
plt.plot(x,y,linestyle = 'dashed' )

# %%
x = [1, 3, 5, 7]
y = [50, 60, 70,80]

# %%
#Line Width
#markerfacecolor - mfc
plt.plot(x,y,linewidth  = 3, color = 'r',marker ='o', mfc= 'b')

# %%
plt.plot(y,marker='X',c='r')

# %%
#Multiple Lines
x = [1, 3, 5, 7]
y = [30, 20, 70, 40]
z = [10, 30, 20, 60]
plt.plot(x,y,z)

# %%
#Multiple Lines
x = [1, 3, 5, 7]
y = [30, 20, 70, 40]
z = [10, 30, 20, 60]
plt.plot(x,y,x,z)

# %%
#Multiple Lines
x = [1, 3, 5, 7]
y = [30, 20, 70, 40]
z = [10, 30, 20, 60]
plt.plot(x,y)
plt.show()
plt.plot(x,z)
plt.show()
plt.plot(z)

# %%
x = [0,1, 2, 3, 4]
plt.figure(figsize=(8,5),dpi=60)
plt.plot(x,y1,color='b',linewidth=4,linestyle='dashdot')
plt.plot(x,y2,color='#F94C66',linewidth=4,linestyle='--')
plt.show()

# %%
#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
#linestyle or ls
#linewidth or lw
#markersize or ms
#markeredgecolor or mec
#markeredgewidth or mew
#markerfacecolor or mfc

# %%
x = [0,1, 2, 3, 4]
plt.figure(figsize=(8,5),dpi=60)
plt.plot(x,y1,color='b',linewidth=4,linestyle='dashdot',marker='*',markersize=10)
plt.plot(x,y2,color='#F94C66',linewidth=4,linestyle='--',marker='<',markersize=20,markerfacecolor='k')
plt.show()

# %%
#'o' -Circle
#'g'- Green
plt.plot(x,y1,'o:g')

# %% [markdown]
# # Labels and Title

# %%
x = [1, 3, 5, 7]
y = [30, 20, 70, 40]
z = [10, 30, 20, 60]
plt.figure(dpi=60)
plt.plot(x,y)
plt.plot(x,z)
plt.title("x vs y")
plt.legend(["y","z"])
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
#Formatting the style

# %%
x = [1, 3, 5, 7]
y = [30, 20, 70, 40]
z = [10, 30, 20, 60]
plt.plot(x, y)
plt.plot(x, z)
plt.title("x vs y and z")
plt.legend(["y","z"],  loc="upper left")
plt.xlabel("x")
plt.ylabel("y and z")
# Out:
# Text(0, 0.5, 'y and z')

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
x = [1, 3, 5, 7]
y = [30, 20, 70, 40]
z = [10, 30, 20, 60]
plt.plot(x, y)
plt.plot(x, z)
plt.title("x vs y and z" ,loc ="center" ,fontsize=20,color='r')
plt.legend(["y","z"],  loc="upper left")
plt.xlabel("x", labelpad=50 )
plt.ylabel("y and z")
#plt.style.use('dark_background')
# Out:
# Text(0, 0.5, 'y and z')

# %%
x = [1, 3, 5, 7]
y = [30, 20, 70, 40]
z = [10, 30, 20, 60]
plt.style.use('seaborn-v0_8')
plt.plot(x, y)
plt.plot(x, z)
plt.title("x vs y and z" ,loc ="center" ,fontsize=20,color='r')
plt.legend(["y","z"],  loc="upper left")
plt.xlabel("x", labelpad=50 )
plt.ylabel("y and z")
# Out:
# Text(0, 0.5, 'y and z')

# %% [markdown]
# ### xticks
# #Get or set the current tick locations and labels of the x-axis.

# %%
x = [1, 3, 5, 7]
y = [30, 20, 70, 40]
z = [10, 30, 20, 60]
#plt.style.use('dark_background')
#plt.style.use('seaborn')
plt.figure(dpi=60)
plt.plot(x, y)
plt.plot(x, z)
#plt.style.use('seaborn')
plt.title("x vs y and z" ,loc ="center" ,fontsize=20,color='r')
plt.legend(["y","z"],  loc="upper left")
plt.xlabel("x", labelpad=50 )
plt.ylabel("y and z")
plt.xticks([0,3,5,7,10])
plt.yticks([10,20,30,40,50,60,70,100])
plt.show()

# %%
x = [1, 3, 5, 7]
y = [30, 20, 70, 40]
z = [10, 30, 20, 60]
plt.plot(x, y)
plt.plot(x, z)
plt.style.use('seaborn-v0_8')
plt.title("x vs y and z" ,loc ="center" ,fontsize=20,color='r')
plt.legend(["y","z"],  loc="upper left")
plt.xlabel("x", labelpad=50 )
plt.ylabel("y and z")
#plt.xticks([1, 3, 5, 7])
#plt.yticks([10,20,30,40,50,60],labels=['10K','20K','30K','40K','50K','60K'])
#plt.ylim()
#plt.ylim()
#plt.xlim(0,7)
plt.ylim(0,200)
# Out:
# (0.0, 200.0)

# %% [markdown]
# ## legend

# %%
year =[2015,2016,2017,2018,2019,2020,2021]
income = [10000,12000,18000,9000,7000,13000,8000]
plt.style.use("fivethirtyeight")
plt.plot(year,income,color='g',label="income")
plt.legend(loc="center left", shadow=True, frameon=True, facecolor="white")
plt.title("Income By Year")
plt.xlabel("Years")
plt.ylabel('Income')
plt.show()

# %% [markdown]
# ### Bar Plots

# %%
year =[2015,2016,2017,2018,2019,2020,2021]
income = [10000,12000,18000,9000,7000,13000,8000]
plt.bar(year,income)
# Out:
# <BarContainer object of 7 artists>

# %%
pup
# Out:
#        Name  Age Country  Height  Weight  avg  income  rooms  family  type gen
# 0      adar    6      SP     113      30   70   16700      7       6     1   M
# 1      agam    6      GR     172      71   92    9200      5       4     2   F
# 2       avi    7     ISR     143      58   82   12000      3       7     1   M
# 3      dani    7      US     160      70   90   15000      4       4     2   M
# 4      dina    7     ISR     110      26   64   10000      6       8     1   F
# 5     efrat    7      EN     115      33   75    8000      5       5     3   F
# 6      ehud    8     ISR     155      66   85   18000      2       7     1   M
# 7       eli    8      GR     155      61   84    8900      7      10     2   M
# 8     ester    8     ISR     130      48   79   19600      2       4     1   F
# 9   evyatar    8     ISR     110      34   72    7600      3       4     1   M
# 10   itamar    8      EN     110      30   71   27000      2       5     2   M
# ...

# %%
mask = pup.groupby("Country")["income"].mean()

# %%
mask
# Out:
# Country
# EN     20575.0
# FR     25925.0
# GR     18225.0
# ISR    18900.0
# SP     16550.0
# US     22200.0
# Name: income, dtype: float64

# %%
mask.index
# Out:
# Index(['EN', 'FR', 'GR', 'ISR', 'SP', 'US'], dtype='object', name='Country')

# %%
mask
# Out:
# Country
# EN     20575.0
# FR     25925.0
# GR     18225.0
# ISR    18900.0
# SP     16550.0
# US     22200.0
# Name: income, dtype: float64

# %%
plt.bar(mask.index,mask)
# Out:
# <BarContainer object of 6 artists>

# %%
#year =[2015,2016,2017,2018,2019,2020,2021]
#income = [10000,12000,18000,9000,7000,13000,8000]
plt.bar(mask.index,mask,color='c')
plt.title("Average By Country")
plt.xlabel("Country")
plt.ylabel('Income')
plt.show()

# %%
year = np.arange(2015,2022)
income1 = np.random.randint(10000,20000,7)
income2 = np.random.randint(5000,20000,7)

# %%
print (year)
print(income1)
print(income2)
# Out:
# [2015 2016 2017 2018 2019 2020 2021]
# [11234 18597 14256 19093 15753 19361 19624]
# [19776  6233 13081 18346  5062 12784  6233]

# %%
plt.style.use('seaborn-v0_8')
plt.figure(figsize=(6,6))
plt.bar(year,income1,color='c')
plt.bar(year,income2,color='r')
plt.title("Income By Year")
plt.xlabel("Years")
plt.ylabel('Income')
plt.show()

# %%
plt.style.use('seaborn-v0_8')
plt.figure(figsize=(6,6))
plt.bar(year,income1,color='c')
plt.bar(year,income2, width=0.4,color='r')
plt.title("Income By Year")
plt.xlabel("Years")
plt.ylabel('Income')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(year,income1, width=-0.2,color='c',align='edge')
plt.bar(year,income2, width=0.2,color='r',align='edge')
plt.title("Income By Year")
plt.xlabel("Years")
plt.ylabel('Income')
plt.show()

# %% [markdown]
# ## stackplot bar

# %%
plt.figure(figsize=(6,6))
plt.bar(year,income1,color='c',bottom=income2,label="Income1")
plt.bar(year,income2,color='r',label="Income2")
plt.title("Income By Year")
plt.xlabel("Years")
plt.ylabel('Income')
plt.legend()
plt.show()

# %% [markdown]
# ## horizontal bar plot

# %%
year =[2015,2016,2017,2018,2019,2020,2021]
income = [10000,12000,18000,9000,7000,13000,8000]
plt.barh(year,income,color='c')
plt.title("Income By Year")
plt.ylabel("Years")
plt.xlabel('Income')
plt.show()

# %% [markdown]
# ## Histograms

# %%
nums = np.random.randn(100)
print(nums)
# Out:
# [ 0.96480154  0.00497408 -1.00634147  0.4837195   0.93331568  0.52848417
#   0.04968844 -1.44952222 -0.04710153 -0.02887711  0.56551514  2.08571305
#   0.35288306 -1.57293634 -0.52268128  0.05556235 -0.04142971 -0.12153364
#  -0.60631858  1.81628621  0.29010439 -1.54317724 -1.200926    1.35028749
#   0.23251307  0.58277608 -1.03534764  0.07008992  1.19011951 -0.27259341
#   2.04954151 -0.7231251   0.43550339  0.0426968  -1.02193865  2.13555335
#   1.49144792 -1.16238445  0.19114142  0.43647533  0.27345508  0.81067054
#   0.03401277 -1.46017324 -0.34968489 -1.41305091 -0.62712913  0.96665985
#  -1.13003984 -0.20751143 -1.4982914  -1.85595442  0.39078078 -1.14731233
#   0.59725028  1.14689461  0.41444472 -0.11928091  1.13726455  1.32379203
#  -1.15680386 -0.13989578 -1.0539352   0.3731424   2.72893868 -0.83851567
#   0.39474598 -0.846987   -0.34442969 -1.20303071  1.20473073 -1.001599
#   0.39424348 -1.43317677  2.31995922  1.05956304  0.16513773 -0.45795854
# ...

# %%
plt.hist(nums)
# Out:
# (array([11., 11.,  7., 18., 24.,  7., 12.,  2.,  6.,  2.]),
#  array([-1.85595442, -1.39746511, -0.9389758 , -0.48048649, -0.02199718,
#          0.43649213,  0.89498144,  1.35347075,  1.81196006,  2.27044937,
#          2.72893868]),
#  <BarContainer object of 10 artists>)

# %%
titanic["age"][titanic["pclass"] == 1]
# Out:
# 1      38.0
# 3      35.0
# 6      54.0
# 11     58.0
# 23     28.0
#        ...
# 871    47.0
# 872    33.0
# 879    56.0
# 887    19.0
# 889    26.0
# Name: age, Length: 216, dtype: float64

# %%
titanic["age"][titanic["pclass"] == 1].min()
# Out:
# 0.92

# %%
titanic["age"][titanic["pclass"] == 1].max()
# Out:
# 80.0

# %%
titanic["age"][titanic["pclass"] == 1].value_counts().sort_index()
# Out:
# age
# 0.92     1
# 2.00     1
# 4.00     1
# 11.00    1
# 14.00    1
# 15.00    1
# 16.00    3
# 17.00    3
# 18.00    4
# 19.00    5
# 21.00    3
# 22.00    5
# 23.00    3
# 24.00    7
# 25.00    3
# 26.00    2
# 27.00    4
# 28.00    4
# 29.00    3
# 30.00    6
# 31.00    5
# 32.00    2
# 33.00    4
# 34.00    1
# 35.00    9
# 36.00    9
# 37.00    3
# 38.00    6
# 39.00    5
# 40.00    5
# 41.00    1
# 42.00    4
# 43.00    1
# 44.00    3
# 45.00    5
# 45.50    1
# 46.00    2
# 47.00    5
# 48.00    5
# 49.00    5
# 50.00    5
# 51.00    3
# 52.00    4
# 53.00    1
# 54.00    4
# 55.00    1
# 56.00    4
# 58.00    5
# 60.00    3
# 61.00    2
# 62.00    3
# 63.00    1
# 64.00    2
# 65.00    2
# 70.00    1
# 71.00    2
# 80.00    1
# Name: count, dtype: int64

# %%
first_class = titanic[titanic["pclass"] == 1]["age"]
second_class = titanic[titanic["pclass"] == 2]["age"]
third_class = titanic[titanic["pclass"] == 3]["age"]
plt.hist(first_class, label="1st Class", alpha=0.5, color="#f1c40f", bins=20)
plt.hist(second_class, label="2nd Class", alpha=0.5, color="#3498db", bins=20)
plt.hist(third_class, label="3rd Class", alpha=0.5, color="#e74c3c", bins=20)
plt.legend()
plt.title("Titanic Passenger Ages")
#plt.xlabel("Passenger Age")
# Out:
# Text(0.5, 1.0, 'Titanic Passenger Ages')

# %% [markdown]
# ### Scatter Plots

# %%
pup.head()
# Out:
#    Name  Age Country  Height  Weight  avg  income  rooms  family  type gen
# 0  adar    6      SP     113      30   70   16700      7       6     1   M
# 1  agam    6      GR     172      71   92    9200      5       4     2   F
# 2   avi    7     ISR     143      58   82   12000      3       7     1   M
# 3  dani    7      US     160      70   90   15000      4       4     2   M
# 4  dina    7     ISR     110      26   64   10000      6       8     1   F

# %%
f_heigh =pup['Height'][pup['gen']=='F']
f_Weight=pup['Weight'][pup['gen']=='F']
m_heigh =pup['Height'][pup['gen']=='M']
m_Weight=pup['Weight'][pup['gen']=='M']

# %%
plt.figure(figsize=(6,6))
plt.scatter(x=f_heigh,y=f_Weight,  label='Female')
plt.scatter(x=m_heigh,y=m_Weight,color='r',  label='Male')
plt.legend()
plt.xlabel("Height (cm)")
plt.ylabel("Weight (kg)")
plt.show()

# %% [markdown]
# ## Pie Charts

# %%
pup.head()

# %%
mask=pup.groupby("Country")["income"].mean()
print(mask)
# Out:
# Country
# EN     20575.0
# FR     25925.0
# GR     18225.0
# ISR    18900.0
# SP     16550.0
# US     22200.0
# Name: income, dtype: float64

# %%
plt.pie(mask)
plt.show()

# %%
plt.pie(mask,labels=mask.index)
plt.show()

# %%
plt.pie(mask,labels=mask.index, autopct="%1.2f%%")
plt.show()

# %%
plt.pie(mask,labels=mask.index, autopct="%1.2f%%", explode=(0,0.2,0.1,0,0,0))
plt.show()

# %%
plt.pie(mask,labels=mask.index, autopct="%1.2f%%", explode=(0,0.2,0.1,0,0,0),shadow=True)
plt.show()

# %% [markdown]
# ### Subplots

# %%
plt.figure(figsize=(10,4))
#num rows
#num columns
plt.subplot(1,3,1)
plt.subplot(1,3,2)
plt.subplot(1,3,3)
# Out:
# <Axes: >

# %%
#var=pup[pup["Country"]=="ISR"][["income"]]
mask=pup.groupby("Country")["income"].mean()
mask1=pup.groupby("Country")["income"].min()
mask2=pup.groupby("Country")["income"].max()
print(mask2)
# Out:
# Country
# EN     30000
# FR     45000
# GR     42000
# ISR    54100
# SP     22000
# US     34500
# Name: income, dtype: int64

# %%
plt.bar(mask.index,mask)
plt.bar(mask1.index,mask1)
plt.bar(mask2.index,mask2)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.figure(dpi=60)
plt.bar(mask.index,mask)
plt.figure(dpi=60)
plt.bar(mask1.index,mask1)
plt.figure(dpi=60)
plt.bar(mask2.index,mask2)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.figure(figsize=(10,4))
plt.suptitle("Title 1", fontsize=20,c='g')

plt.subplot(1,3,1)
plt.plot(mask.index, mask,color='y')
plt.title("Average by Country")

plt.subplot(1,3,2)
plt.plot(mask.index, mask1,color='r')
plt.title("MIN by Country")

plt.subplot(1,3,3)
plt.plot(mask.index, mask2)
plt.title("MAX by Country")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,8),dpi=60)
#plt.suptitle("Title 1", fontsize=20)

plt.subplot(2,2,1)
plt.plot(mask.index, mask,color='y')
plt.title("Average by Country")

plt.subplot(2,2,2)
plt.plot(mask.index, mask1,color='r')
plt.title("MIN by Country")

plt.subplot(2,2,3)
plt.plot(mask.index, mask2)
plt.title("MAX by Country")

#plt.tight_layout()
plt.show()

# %%
f_heigh =pup['Height'][pup['gen']=='F']
f_Weight=pup['Weight'][pup['gen']=='F']
m_heigh =pup['Height'][pup['gen']=='M']
m_Weight=pup['Weight'][pup['gen']=='M']
f_age=pup["Age"][pup['gen']=='F']
m_age=pup["Age"][pup['gen']=='M']

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.scatter(y=f_heigh,x=f_Weight,  label='Female')
plt.scatter(y=m_heigh,x=m_Weight,color='r',  label='Male')
plt.legend()
plt.ylabel("Height (cm)")
plt.xlabel("Weight (kg)")

plt.subplot(1,2,2)
plt.scatter(x=f_age,y=f_heigh,  label='Female')
plt.scatter(x=m_age,y=m_heigh,  label='Male')
plt.legend()
plt.ylabel("Height (cm)")
plt.xlabel("Age")
plt.show()

# %%
#Share axis

# %%
plt.figure(figsize=(10,4))
plt.suptitle("Title 1", fontsize=20)

ax=plt.subplot(1,3,1)
plt.plot(mask.index, mask,color='y')
plt.title("Average by Country")

plt.subplot(1,3,2,sharey =ax)
plt.plot(mask.index, mask1,color='r')
plt.title("MIN by Country")

plt.subplot(1,3,3,sharey =ax)
plt.plot(mask.index, mask2)
plt.title("MAX by Country")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.suptitle("Title 1", fontsize=20)

plt.subplot(3,1,1)
plt.plot(mask.index, mask,color='y')
plt.title("Average by Country")

plt.subplot(3,1,2)
plt.plot(mask.index, mask1,color='r')
plt.title("MIN by Country")

plt.subplot(3,1,3)
plt.plot(mask.index, mask2)
plt.title("MAX by Country")

plt.tight_layout()
plt.show()

# %%
Countries.head()
# Out:
#    year country  population  world_population
# 0  2020   China  1439323776        7794798739
# 1  2019   China  1433783686        7713468100
# 2  2018   China  1427647786        7631091040
# 3  2017   China  1421021791        7547858925
# 4  2016   China  1414049351        7464022049

# %%
Countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4195 entries, 0 to 4194
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              4195 non-null   int64
#  1   country           4195 non-null   object
#  2   population        4195 non-null   int64
#  3   world_population  4195 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 131.2+ KB

# %%
Countries.country.value_counts()
# Out:
# country
# China               18
# Qatar               18
# Kuwait              18
# Croatia             18
# Moldova             18
#                     ..
# Faeroe Islands      17
# Sint Maarten        17
# Monaco              17
# Turks and Caicos    17
# Holy See            17
# Name: count, Length: 235, dtype: int64

# %%
plt.hist(Countries.country.value_counts())
# Out:
# (array([ 35.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0., 200.]),
#  array([17. , 17.1, 17.2, 17.3, 17.4, 17.5, 17.6, 17.7, 17.8, 17.9, 18. ]),
#  <BarContainer object of 10 artists>)

# %%
Countries.population.value_counts()
# Out:
# population
# 801           2
# 5364          2
# 56672         2
# 1439323776    1
# 1293119       1
#              ..
# 2797932       1
# 2537157       1
# 11818619      1
# 11694719      1
# 908           1
# Name: count, Length: 4192, dtype: int64

# %%
plt.hist(Countries.population)
plt.show()

# %%
Countries.head(30)

# %%
ctr=Countries[['year','population']][Countries.country.isin(['China','India'])]
a=ctr.groupby('year').mean()

# %%
a
# Out:
#         population
# year
# 1955  5.110611e+08
# 1960  5.554779e+08
# 1965  6.116711e+08
# 1970  6.913956e+08
# 1975  7.746719e+08
# 1980  8.495210e+08
# 1985  9.299747e+08
# 1990  1.025081e+09
# 1995  1.102422e+09
# 2000  1.173563e+09
# 2005  1.239193e+09
# 2010  1.301546e+09
# 2015  1.358500e+09
# 2016  1.369283e+09
# 2017  1.379849e+09
# 2018  1.390145e+09
# 2019  1.400101e+09
# 2020  1.409664e+09

# %%
#ctr=Countries[['year','population']]#[Countries.country.isin(['China','India'])]
#a=ctr.groupby('year').mean()
x=a.index
y=a.values

# %%
print(x)
# Out:
# Index([1955, 1960, 1965, 1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005, 2010,
#        2015, 2016, 2017, 2018, 2019, 2020],
#       dtype='int64', name='year')

# %%
print(y)
# Out:
# [[5.11061074e+08]
#  [5.55477868e+08]
#  [6.11671146e+08]
#  [6.91395593e+08]
#  [7.74671891e+08]
#  [8.49521040e+08]
#  [9.29974684e+08]
#  [1.02508074e+09]
#  [1.10242156e+09]
#  [1.17356316e+09]
#  [1.23919315e+09]
#  [1.30154589e+09]
#  [1.35850014e+09]
#  [1.36928330e+09]
#  [1.37984929e+09]
#  [1.39014503e+09]
#  [1.40010072e+09]
#  [1.40966408e+09]]

# %%
plt.figure(figsize=(6,6))
plt.plot(x,y)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.plot(x,y)
plt.show()

# %%
mask=Countries[(Countries["country"].isin(['China','India']))& (Countries["year"]>=2018)]

# %%
mask.count()
# Out:
# year                6
# country             6
# population          6
# world_population    6
# dtype: int64

# %%
mask.head()
# Out:
#     year country  population  world_population
# 0   2020   China  1439323776        7794798739
# 1   2019   China  1433783686        7713468100
# 2   2018   China  1427647786        7631091040
# 18  2020   India  1380004385        7794798739
# 19  2019   India  1366417754        7713468100

# %%
mask.info()

# %%
x=mask.year.sort_values()
y=mask.population.sort_values()
plt.figure(figsize=(12,6))
plt.plot(x,y)
plt.show()

# %%
titanic[titanic["pclass"] == 1]["age"].value_counts()
# Out:
# age
# 36.00    9
# 35.00    9
# 24.00    7
# 38.00    6
# 30.00    6
# 22.00    5
# 31.00    5
# 47.00    5
# 45.00    5
# 49.00    5
# 40.00    5
# 19.00    5
# 48.00    5
# 58.00    5
# 39.00    5
# 50.00    5
# 27.00    4
# 56.00    4
# 18.00    4
# 33.00    4
# 52.00    4
# 42.00    4
# 54.00    4
# 28.00    4
# 25.00    3
# 16.00    3
# 23.00    3
# 17.00    3
# 60.00    3
# 51.00    3
# 29.00    3
# 21.00    3
# 62.00    3
# 37.00    3
# 44.00    3
# 65.00    2
# 64.00    2
# 61.00    2
# 46.00    2
# 26.00    2
# 71.00    2
# 32.00    2
# 80.00    1
# 15.00    1
# 70.00    1
# 43.00    1
# 53.00    1
# 55.00    1
# 41.00    1
# 34.00    1
# 4.00     1
# 14.00    1
# 45.50    1
# 0.92     1
# 2.00     1
# 63.00    1
# 11.00    1
# Name: count, dtype: int64

# %%
first_class = titanic[titanic["pclass"] == 1]["age"]
second_class = titanic[titanic["pclass"] == 2]["age"]
third_class = titanic[titanic["pclass"] == 3]["age"]

plt.figure(figsize=(10,4))

plt.subplot(1,3,1)
plt.hist(first_class, label="1st Class", color="#f1c40f", bins=20)
plt.title("1st Class")

plt.subplot(1,3,2)
plt.hist(second_class, label="2nd Class", color="#3498db", bins=20)
plt.title("2nd Class")


plt.subplot(1,3,3)
plt.hist(third_class, label="3rd Class", color="#e74c3c", bins=20)
plt.title("3rd Class")
# Out:
# Text(0.5, 1.0, '3rd Class')

# %%
first_class = titanic[titanic["pclass"] == 1]["age"]
second_class = titanic[titanic["pclass"] == 2]["age"]
third_class = titanic[titanic["pclass"] == 3]["age"]

plt.figure(figsize=(10,4))

ax = plt.subplot(1,3,1)
plt.hist(first_class, label="1st Class", color="#f1c40f", bins=20)
plt.title("1st Class")

plt.subplot(1,3,2, sharey=ax, sharex=ax)
plt.hist(second_class, label="2nd Class", color="#3498db", bins=20)
plt.title("2nd Class")


plt.subplot(1,3,3, sharey=ax , sharex=ax)
plt.hist(third_class, label="3rd Class", color="#e74c3c", bins=20)
plt.title("3rd Class")
# Out:
# Text(0.5, 1.0, '3rd Class')
