# %%
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv("data/products.csv")
fl =sb.load_dataset("flights")
titanic =sb.load_dataset("titanic")

# %%
fl.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.head()
# Out:
#    ProductID                   ProductName  UnitPrice  CategoryID        Date
# 0          1                          Chai      18.00           1  22/11/2024  \
# 1          2                         Chang      19.00           1  23/11/2024
# 2          3                 Aniseed Syrup      10.00           2  24/11/2024
# 3          4  Chef Anton's Cajun Seasoning      22.00           2  25/11/2024
# 4          5        Chef Anton's Gumbo Mix      21.35           2  26/11/2024
#
#        Date1
# 0  5/31/2023
# 1   6/1/2023
# 2   6/2/2023
# 3   6/3/2023
# 4   6/4/2023

# %%
df.CategoryID.value_counts()
# Out:
# CategoryID
# 3    13
# 1    12
# 2    12
# 8    12
# 4    10
# 5     7
# 6     6
# 7     5
# Name: count, dtype: int64

# %%
df.CategoryID.value_counts().sort_index()
# Out:
# CategoryID
# 1    12
# 2    12
# 3    13
# 4    10
# 5     7
# 6     6
# 7     5
# 8    12
# Name: count, dtype: int64

# %%
df.CategoryID
# Out:
# 0     1
# 1     1
# 2     2
# 3     2
# 4     2
#      ..
# 72    8
# 73    7
# 74    1
# 75    1
# 76    2
# Name: CategoryID, Length: 77, dtype: int64

# %%
df.CategoryID.plot()
# Out:
# <Axes: >

# %%
df.CategoryID.value_counts()#.plot()
# Out:
# CategoryID
# 3    13
# 1    12
# 2    12
# 8    12
# 4    10
# 5     7
# 6     6
# 7     5
# Name: count, dtype: int64

# %%
df.CategoryID.value_counts().plot()
# Out:
# <Axes: xlabel='CategoryID'>

# %%
df.CategoryID.value_counts().sort_index()#.plot()
# Out:
# CategoryID
# 1    12
# 2    12
# 3    13
# 4    10
# 5     7
# 6     6
# 7     5
# 8    12
# Name: count, dtype: int64

# %%
df.CategoryID.value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='CategoryID'>

# %%
#Sort by index
df.CategoryID.value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='CategoryID'>

# %%
#Sort by values
df.CategoryID.value_counts().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='CategoryID'>

# %%
df.CategoryID.value_counts().sort_values().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
titanic.survived.value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
titanic.survived.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
titanic.sex.value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titanic.sex.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df[["CategoryID","UnitPrice"]].value_counts()
# Out:
# CategoryID  UnitPrice
# 1           18.00        4
#             14.00        2
#             4.50         1
# 5           21.00        1
# 6           39.00        1
#                         ..
# 3           14.00        1
#             12.75        1
#             12.50        1
#             10.00        1
# 8           62.50        1
# Name: count, Length: 73, dtype: int64

# %%
df[["CategoryID","UnitPrice"]].value_counts().plot()
# Out:
# <Axes: xlabel='CategoryID,UnitPrice'>

# %%
val = df[["CategoryID","UnitPrice"]]
val.plot(x="CategoryID",y="UnitPrice")
# Out:
# <Axes: xlabel='CategoryID'>

# %%
val.plot(kind="scatter",x="CategoryID",y="UnitPrice")
# Out:
# <Axes: xlabel='CategoryID', ylabel='UnitPrice'>

# %%
val.plot(kind="bar",x="CategoryID",y="UnitPrice")
# Out:
# <Axes: xlabel='CategoryID'>

# %%
val.head().plot(kind="bar",x="CategoryID",y="UnitPrice")
# Out:
# <Axes: xlabel='CategoryID'>

# %%
df
# Out:
#     ProductID                      ProductName  UnitPrice  CategoryID
# 0           1                             Chai      18.00           1  \
# 1           2                            Chang      19.00           1
# 2           3                    Aniseed Syrup      10.00           2
# 3           4     Chef Anton's Cajun Seasoning      22.00           2
# 4           5           Chef Anton's Gumbo Mix      21.35           2
# ..        ...                              ...        ...         ...
# 72         73                       Rad Kaviar      15.00           8
# 73         74                    Longlife Tofu      10.00           7
# 74         75             Rhanbrau Klosterbier       7.75           1
# 75         76                     Lakkalikaari      18.00           1
# 76         77  Original Frankfurter grane Soae      13.00           2
#
#           Date      Date1
# 0   22/11/2024  5/31/2023
# 1   23/11/2024   6/1/2023
# 2   24/11/2024   6/2/2023
# ...

# %%
df.groupby("CategoryID")["UnitPrice"].mean().round(1)
# Out:
# CategoryID
# 1    38.0
# 2    23.1
# 3    25.2
# 4    28.7
# 5    20.2
# 6    54.0
# 7    32.4
# 8    20.7
# Name: UnitPrice, dtype: float64

# %%
df.groupby("CategoryID")["UnitPrice"].mean().round(1).plot()
# Out:
# <Axes: xlabel='CategoryID'>

# %%
df.groupby("CategoryID")["UnitPrice"].mean().round(1).plot(kind="bar")
# Out:
# <Axes: xlabel='CategoryID'>

# %%
fl.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
fl.set_index("month",inplace=True)

# %%
fl.head()
# Out:
#        year  passengers
# month
# Jan    1949         112
# Feb    1949         118
# Mar    1949         132
# Apr    1949         129
# May    1949         121

# %%
fl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# CategoricalIndex: 144 entries, Jan to Dec
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   passengers  144 non-null    int64
# dtypes: int64(2)
# memory usage: 2.8 KB

# %%
fl.passengers.plot()
# Out:
# <Axes: xlabel='month'>

# %%
fl
# Out:
#        year  passengers
# month
# Jan    1949         112
# Feb    1949         118
# Mar    1949         132
# Apr    1949         129
# May    1949         121
# ...     ...         ...
# Aug    1960         606
# Sep    1960         508
# Oct    1960         461
# Nov    1960         390
# Dec    1960         432
#
# [144 rows x 2 columns]

# %%
fl.groupby("year")["passengers"].sum()
# Out:
# year
# 1949    1520
# 1950    1676
# 1951    2042
# 1952    2364
# 1953    2700
# 1954    2867
# 1955    3408
# 1956    3939
# 1957    4421
# 1958    4572
# 1959    5140
# 1960    5714
# Name: passengers, dtype: int64

# %%
fl.groupby("year").sum().plot()
# Out:
# <Axes: xlabel='year'>

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.pclass
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
titanic.pclass.value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
titanic.pclass.value_counts().plot()
# Out:
# <Axes: xlabel='pclass'>

# %%
titanic.pclass.value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='pclass'>

# %%
titanic.pclass.value_counts().plot(kind ="bar")
# Out:
# <Axes: xlabel='pclass'>

# %%
titanic.pclass.value_counts().sort_values()
# Out:
# pclass
# 2    184
# 1    216
# 3    491
# Name: count, dtype: int64

# %%
titanic.pclass.value_counts().sort_values().plot(kind ="bar")
# Out:
# <Axes: xlabel='pclass'>

# %%
titanic.pclass.value_counts().sort_index().plot(kind ="bar")
# Out:
# <Axes: xlabel='pclass'>

# %%
titanic[titanic["sex"]=="male"]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class
# 0           0       3  male  22.0      1      0   7.2500        S   Third  \
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic[titanic["sex"]=="female"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 1           1       1  female  38.0      1      0  71.2833        C   First  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic[titanic["sex"]=="female"].survived.value_counts()
# Out:
# survived
# 1    233
# 0     81
# Name: count, dtype: int64

# %%
titanic[titanic["sex"]=="female"].survived.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='survived'>

# %%
titanic[titanic["sex"]=="female"].survived.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
titanic[titanic["sex"]=="male"].survived.value_counts()
# Out:
# survived
# 0    468
# 1    109
# Name: count, dtype: int64

# %%
titanic[titanic["sex"]=="male"].survived.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
titanic[titanic["sex"]=="male"].groupby("pclass")["survived"].count()
# Out:
# pclass
# 1    122
# 2    108
# 3    347
# Name: survived, dtype: int64

# %%
titanic[titanic["sex"]=="male"].groupby("pclass")["survived"].count().plot(kind="pie")
# Out:
# <Axes: ylabel='survived'>

# %%
titanic.groupby("sex")["survived"].count().plot(kind="pie")
# Out:
# <Axes: ylabel='survived'>

# %%
df.groupby("CategoryID")["UnitPrice"].mean()
# Out:
# CategoryID
# 1    37.979167
# 2    23.062500
# 3    25.160000
# 4    28.730000
# 5    20.250000
# 6    54.006667
# 7    32.370000
# 8    20.682500
# Name: UnitPrice, dtype: float64

# %%
df.groupby("CategoryID")["UnitPrice"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='CategoryID'>

# %%
df.groupby("CategoryID")["UnitPrice"].mean().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='CategoryID'>

# %%
fl.head()
# Out:
#        year  passengers
# month
# Jan    1949         112
# Feb    1949         118
# Mar    1949         132
# Apr    1949         129
# May    1949         121

# %%
fl.groupby("year").mean()
# Out:
#       passengers
# year
# 1949  126.666667
# 1950  139.666667
# 1951  170.166667
# 1952  197.000000
# 1953  225.000000
# 1954  238.916667
# 1955  284.000000
# 1956  328.250000
# 1957  368.416667
# 1958  381.000000
# 1959  428.333333
# 1960  476.166667

# %%
fl.groupby("year").mean().plot()
# Out:
# <Axes: xlabel='year'>

# %%
fl =sb.load_dataset("flights")

# %%
fl.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
fl.groupby("month").passengers.sum()
# Out:
# month
# Jan    2901
# Feb    2820
# Mar    3242
# Apr    3205
# May    3262
# Jun    3740
# Jul    4216
# Aug    4213
# Sep    3629
# Oct    3199
# Nov    2794
# Dec    3142
# Name: passengers, dtype: int64

# %%
fl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
val=fl.groupby("month")["passengers"].mean()

# %%
fl.groupby("month")["passengers"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='month'>

# %%
val.plot()
# Out:
# <Axes: xlabel='month'>

# %%
fl.groupby(["year","month"])["passengers"].mean()
# Out:
# year  month
# 1949  Jan      112.0
#       Feb      118.0
#       Mar      132.0
#       Apr      129.0
#       May      121.0
#                ...
# 1960  Aug      606.0
#       Sep      508.0
#       Oct      461.0
#       Nov      390.0
#       Dec      432.0
# Name: passengers, Length: 144, dtype: float64

# %%
fl.groupby(["year","month"])["passengers"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='year,month'>

# %%
mask =fl["year"].between (1950,1955)
fl[mask]
# Out:
#     year month  passengers
# 12  1950   Jan         115
# 13  1950   Feb         126
# 14  1950   Mar         141
# 15  1950   Apr         135
# 16  1950   May         125
# ..   ...   ...         ...
# 79  1955   Aug         347
# 80  1955   Sep         312
# 81  1955   Oct         274
# 82  1955   Nov         237
# 83  1955   Dec         278
#
# [72 rows x 3 columns]

# %%
mask =fl["year"].between (1950,1955)
fl[mask].groupby("year").mean(numeric_only=True)
# Out:
#       passengers
# year
# 1950  139.666667
# 1951  170.166667
# 1952  197.000000
# 1953  225.000000
# 1954  238.916667
# 1955  284.000000

# %%
mask =fl["year"].between (1950,1955)
fl[mask].groupby("year").mean(numeric_only=True).plot(kind="bar")
# Out:
# <Axes: xlabel='year'>

# %%
fl[mask].groupby(["year","month"])["passengers"].mean()
# Out:
# year  month
# 1950  Jan      115.0
#       Feb      126.0
#       Mar      141.0
#       Apr      135.0
#       May      125.0
#                ...
# 1955  Aug      347.0
#       Sep      312.0
#       Oct      274.0
#       Nov      237.0
#       Dec      278.0
# Name: passengers, Length: 72, dtype: float64

# %%
fl[mask].groupby(["year","month"])["passengers"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='year,month'>

# %%
fl[mask].groupby(["year","month"])["passengers"].mean().unstack()
# Out:
# month    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct
# year
# 1950   115.0  126.0  141.0  135.0  125.0  149.0  170.0  170.0  158.0  133.0  \
# 1951   145.0  150.0  178.0  163.0  172.0  178.0  199.0  199.0  184.0  162.0
# 1952   171.0  180.0  193.0  181.0  183.0  218.0  230.0  242.0  209.0  191.0
# 1953   196.0  196.0  236.0  235.0  229.0  243.0  264.0  272.0  237.0  211.0
# 1954   204.0  188.0  235.0  227.0  234.0  264.0  302.0  293.0  259.0  229.0
# 1955   242.0  233.0  267.0  269.0  270.0  315.0  364.0  347.0  312.0  274.0
#
# month    Nov    Dec
# year
# 1950   114.0  140.0
# 1951   146.0  166.0
# 1952   172.0  194.0
# 1953   180.0  201.0
# 1954   203.0  229.0
# 1955   237.0  278.0

# %%
fl[mask].groupby(["year","month"])["passengers"].mean().unstack().plot()
# Out:
# <Axes: xlabel='year'>

# %%
fl[mask].groupby(["year","month"])["passengers"].mean()
# Out:
# year  month
# 1950  Jan      115.0
#       Feb      126.0
#       Mar      141.0
#       Apr      135.0
#       May      125.0
#                ...
# 1955  Aug      347.0
#       Sep      312.0
#       Oct      274.0
#       Nov      237.0
#       Dec      278.0
# Name: passengers, Length: 72, dtype: float64

# %%
fl[mask].groupby(["year","month"])["passengers"].mean().unstack(level=0)
# Out:
# year    1950   1951   1952   1953   1954   1955
# month
# Jan    115.0  145.0  171.0  196.0  204.0  242.0
# Feb    126.0  150.0  180.0  196.0  188.0  233.0
# Mar    141.0  178.0  193.0  236.0  235.0  267.0
# Apr    135.0  163.0  181.0  235.0  227.0  269.0
# May    125.0  172.0  183.0  229.0  234.0  270.0
# Jun    149.0  178.0  218.0  243.0  264.0  315.0
# Jul    170.0  199.0  230.0  264.0  302.0  364.0
# Aug    170.0  199.0  242.0  272.0  293.0  347.0
# Sep    158.0  184.0  209.0  237.0  259.0  312.0
# Oct    133.0  162.0  191.0  211.0  229.0  274.0
# Nov    114.0  146.0  172.0  180.0  203.0  237.0
# Dec    140.0  166.0  194.0  201.0  229.0  278.0

# %%
fl[mask].groupby(["year","month"])["passengers"].mean().unstack(level=0).plot()
# Out:
# <Axes: xlabel='month'>

# %%
fl[mask].groupby(["year","month"])["passengers"].mean().unstack(level=1)
# Out:
# month    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct
# year
# 1950   115.0  126.0  141.0  135.0  125.0  149.0  170.0  170.0  158.0  133.0  \
# 1951   145.0  150.0  178.0  163.0  172.0  178.0  199.0  199.0  184.0  162.0
# 1952   171.0  180.0  193.0  181.0  183.0  218.0  230.0  242.0  209.0  191.0
# 1953   196.0  196.0  236.0  235.0  229.0  243.0  264.0  272.0  237.0  211.0
# 1954   204.0  188.0  235.0  227.0  234.0  264.0  302.0  293.0  259.0  229.0
# 1955   242.0  233.0  267.0  269.0  270.0  315.0  364.0  347.0  312.0  274.0
#
# month    Nov    Dec
# year
# 1950   114.0  140.0
# 1951   146.0  166.0
# 1952   172.0  194.0
# 1953   180.0  201.0
# 1954   203.0  229.0
# 1955   237.0  278.0

# %%
fl[mask].groupby(["year","month"])["passengers"].mean().unstack(level=0).plot(kind="bar")
# Out:
# <Axes: xlabel='month'>

# %%
fl[mask].groupby(["year","month"])["passengers"].mean().unstack(level=1).plot(kind="bar")
# Out:
# <Axes: xlabel='year'>

# %%
fl[mask].groupby(["year","month"])["passengers"].mean().unstack(level="year").plot()
# Out:
# <Axes: xlabel='month'>

# %%
df1=titanic.groupby(["sex","survived"])["age"].mean()

# %%
df1
# Out:
# sex     survived
# female  0           25.046875
#         1           28.847716
# male    0           31.618056
#         1           27.276022
# Name: age, dtype: float64

# %%
df1.unstack()
# Out:
# survived          0          1
# sex
# female    25.046875  28.847716
# male      31.618056  27.276022

# %%
df1.unstack().plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %%
df1.unstack().rename(columns={0:"died",1:"survived"})
# Out:
# survived       died   survived
# sex
# female    25.046875  28.847716
# male      31.618056  27.276022

# %%
df1.unstack().rename(columns={0:"died",1:"survived"}).plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %%
df1.unstack().rename(columns={0:"died",1:"survived"}).plot()
# Out:
# <Axes: xlabel='sex'>

# %%
pup.groupby(["Age","gen"])["Height"].mean().unstack().plot()
