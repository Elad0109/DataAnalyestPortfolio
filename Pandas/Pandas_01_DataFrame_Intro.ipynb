# %% [markdown]
# # PANDAS

# %% [markdown]
# WHAT IS PANDAS?

# %% [markdown]
# pandas is a Python package that provides fast, flexible, and expressive data structures designed to make working with "relational" or "labeled" data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python. Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis / manipulation tool available in any language. It is already well on its way towards this goal.

# %% [markdown]
# What Can Pandas Do?

# %% [markdown]
# Pandas can cleaning the data like delete or insert rows ,
# contains wrong values, like empty or NULL values,
#  data alignment,group by functionality,

# %% [markdown]
# Installation of Pandas

# %% [markdown]
# C:\Users\Your Name>pip install pandas

# %% [markdown]
# # Import Pandas Package

# %%
import pandas as pd

# %%
#Pandas work with Series or Data frame
#A Pandas Series is like a column in a table.
#A Pandas DataFrame is a table with rows and columns.

# %%
#all values in a series should have the same type. We can create a series by calling pandas.Series()
#Accessing Pandas Series by Using Index
#The values are labeled with their index number. The first value has index 0, the second value has index 1, etc.

# %%
a = [1, 7, 2]

# %%
type(a)
# Out:
# list

# %%
print(a)
# Out:
# [1, 7, 2]

# %%
#a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
type(a)
# Out:
# list

# %%
type(myvar)
# Out:
# pandas.core.series.Series

# %%
print(myvar[1])
# Out:
# 7

# %%
a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
type(myvar)
# Out:
# pandas.core.series.Series

# %%
type(a)
# Out:
# list

# %%
print(myvar["y"])
# Out:
# 7

# %% [markdown]
# # Load Files Into a DataFrame

# %%
#A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.

# %% [markdown]
# ### Load csv file

# %%
#Read data in the same directory that your python process is based or specify full path

# %%
pd.read_csv('customers.csv')
# Out:
#     CustomerID                         CompanyName              ContactName
# 0            1                 Alfreds Futterkiste             Maria Anders  \
# 1            2  Ana Trujillo Emparedados y helados             Ana Trujillo
# 2            3             Antonio Moreno Taquería           Antonio Moreno
# 3            4                     Around the Horn             Thomas Hardy
# 4            5                  Berglunds snabbköp       Christina Berglund
# ..         ...                                 ...                      ...
# 86          87                      Wartian Herkku         Pirkko Koskitalo
# 87          88              Wellington Importadora            Paula Parente
# 88          89                White Clover Markets           Karl Jablonski
# 89          90                         Wilman Kala          Matti Karttunen
# 90          91                      Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
# ...

# %%
df = pd.read_csv("customers.csv")

# %%
df
# Out:
#     CustomerID                         CompanyName              ContactName
# 0            1                 Alfreds Futterkiste             Maria Anders  \
# 1            2  Ana Trujillo Emparedados y helados             Ana Trujillo
# 2            3             Antonio Moreno Taquería           Antonio Moreno
# 3            4                     Around the Horn             Thomas Hardy
# 4            5                  Berglunds snabbköp       Christina Berglund
# ..         ...                                 ...                      ...
# 86          87                      Wartian Herkku         Pirkko Koskitalo
# 87          88              Wellington Importadora            Paula Parente
# 88          89                White Clover Markets           Karl Jablonski
# 89          90                         Wilman Kala          Matti Karttunen
# 90          91                      Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
# ...

# %%
df.head()
# Out:
#    CustomerID                         CompanyName         ContactName
# 0           1                 Alfreds Futterkiste        Maria Anders  \
# 1           2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2           3             Antonio Moreno Taquería      Antonio Moreno
# 3           4                     Around the Horn        Thomas Hardy
# 4           5                  Berglunds snabbköp  Christina Berglund
#
#            ContactTitle                        Address         City Region
# 0  Sales Representative                  Obere Str. 57       Berlin    NaN  \
# 1                 Owner  Avda. de la Constitución 2222  México D.F.    NaN
# 2                 Owner                Mataderos  2312  México D.F.    NaN
# 3  Sales Representative                120 Hanover Sq.       London    NaN
# 4   Order Administrator                Berguvsvägen  8        Luleå    NaN
#
#   PostalCode  Country           Phone             Fax
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['CustomerID', 'CompanyName', 'ContactName', 'ContactTitle', 'Address',
#        'City', 'Region', 'PostalCode', 'Country', 'Phone', 'Fax'],
#       dtype='object')

# %%
products=pd.read_csv("data/Products.csv")

# %%
products.head()
# Out:
#    ProductID                   ProductName  UnitPrice  CategoryID
# 0          1                          Chai      18.00           1
# 1          2                         Chang      19.00           1
# 2          3                 Aniseed Syrup      10.00           2
# 3          4  Chef Anton's Cajun Seasoning      22.00           2
# 4          5        Chef Anton's Gumbo Mix      21.35           2

# %%
products=pd.read_csv(r"C:\Users\jbt\Desktop\9297.32\Python\Pandas\Data\products.csv")

# %%
products
# Out:
#     ProductID                      ProductName  UnitPrice  CategoryID
# 0           1                             Chai      18.00           1
# 1           2                            Chang      19.00           1
# 2           3                    Aniseed Syrup      10.00           2
# 3           4     Chef Anton's Cajun Seasoning      22.00           2
# 4           5           Chef Anton's Gumbo Mix      21.35           2
# ..        ...                              ...        ...         ...
# 72         73                       Rad Kaviar      15.00           8
# 73         74                    Longlife Tofu      10.00           7
# 74         75             Rhanbrau Klosterbier       7.75           1
# 75         76                     Lakkalikaari      18.00           1
# 76         77  Original Frankfurter grane Soae      13.00           2
#
# [77 rows x 4 columns]

# %%
products.columns
# Out:
# Index(['ProductID', 'ProductName', 'UnitPrice', 'CategoryID'], dtype='object')

# %%
type(products)
# Out:
# pandas.core.frame.DataFrame

# %%
ct = pd.read_csv("data/Countries.csv")

# %%
ct
# Out:
#       year   country  population  world_population
# 0     2020     China  1439323776        7794798739
# 1     2019     China  1433783686        7713468100
# 2     2018     China  1427647786        7631091040
# 3     2017     China  1421021791        7547858925
# 4     2016     China  1414049351        7464022049
# ...    ...       ...         ...               ...
# 4190  1975  Holy See         728        4079480606
# 4191  1970  Holy See         644        3700437046
# 4192  1965  Holy See         854        3339583597
# 4193  1960  Holy See         906        3034949748
# 4194  1955  Holy See         908        2773019936
#
# [4195 rows x 4 columns]

# %%
ct.head()
# Out:
#    year country  population  world_population
# 0  2020   China  1439323776        7794798739
# 1  2019   China  1433783686        7713468100
# 2  2018   China  1427647786        7631091040
# 3  2017   China  1421021791        7547858925
# 4  2016   China  1414049351        7464022049

# %%
ct.head(10)
# Out:
#    year country  population  world_population
# 0  2020   China  1439323776        7794798739
# 1  2019   China  1433783686        7713468100
# 2  2018   China  1427647786        7631091040
# 3  2017   China  1421021791        7547858925
# 4  2016   China  1414049351        7464022049
# 5  2015   China  1406847870        7379797139
# 6  2010   China  1368810615        6956823603
# 7  2005   China  1330776380        6541907027
# 8  2000   China  1290550765        6143493823
# 9  1995   China  1240920535        5744212979

# %%
ct.head(100)
# Out:
#     year country  population  world_population
# 0   2020   China  1439323776        7794798739
# 1   2019   China  1433783686        7713468100
# 2   2018   China  1427647786        7631091040
# 3   2017   China  1421021791        7547858925
# 4   2016   China  1414049351        7464022049
# ..   ...     ...         ...               ...
# 95  2015  Brazil   204471769        7379797139
# 96  2010  Brazil   195713635        6956823603
# 97  2005  Brazil   186127103        6541907027
# 98  2000  Brazil   174790340        6143493823
# 99  1995  Brazil   162019896        5744212979
#
# [100 rows x 4 columns]

# %%
#Overriding Headers: Country Population Dataset

# %%
ct = pd.read_csv("data/Countries.csv",names=["yy","count","pop","world pop"])

# %%
ct
# Out:
#         yy     count         pop         world pop
# 0     year   country  population  world_population
# 1     2020     China  1439323776        7794798739
# 2     2019     China  1433783686        7713468100
# 3     2018     China  1427647786        7631091040
# 4     2017     China  1421021791        7547858925
# ...    ...       ...         ...               ...
# 4191  1975  Holy See         728        4079480606
# 4192  1970  Holy See         644        3700437046
# 4193  1965  Holy See         854        3339583597
# 4194  1960  Holy See         906        3034949748
# 4195  1955  Holy See         908        2773019936
#
# [4196 rows x 4 columns]

# %%
ct = pd.read_csv("data/Countries.csv",names=["yy","count","pop","world pop"],header=0)

# %%
ct
# Out:
#         yy     count         pop   world pop
# 0     2020     China  1439323776  7794798739
# 1     2019     China  1433783686  7713468100
# 2     2018     China  1427647786  7631091040
# 3     2017     China  1421021791  7547858925
# 4     2016     China  1414049351  7464022049
# ...    ...       ...         ...         ...
# 4190  1975  Holy See         728  4079480606
# 4191  1970  Holy See         644  3700437046
# 4192  1965  Holy See         854  3339583597
# 4193  1960  Holy See         906  3034949748
# 4194  1955  Holy See         908  2773019936
#
# [4195 rows x 4 columns]

# %%
#Import specific columns
ct = pd.read_csv("data/Countries.csv",names=["year","country","population"],header=0)

# %%
ct.head()
# Out:
#        year     country  population
# 2020  China  1439323776  7794798739
# 2019  China  1433783686  7713468100
# 2018  China  1427647786  7631091040
# 2017  China  1421021791  7547858925
# 2016  China  1414049351  7464022049

# %%
newname = ["year","country","population"]
ct = pd.read_csv("data/Countries.csv",names=newname,header=0)

# %%
ct.head()
# Out:
#        year     country  population
# 2020  China  1439323776  7794798739
# 2019  China  1433783686  7713468100
# 2018  China  1427647786  7631091040
# 2017  China  1421021791  7547858925
# 2016  China  1414049351  7464022049

# %%
newname = ["yy","country","population"]
ct = pd.read_csv("data/Countries.csv",names=newname,header=0,usecols=newname)

# %%
ct.head()
# Out:
#      yy country  population
# 0  2020   China  1439323776
# 1  2019   China  1433783686
# 2  2018   China  1427647786
# 3  2017   China  1421021791
# 4  2016   China  1414049351

# %% [markdown]
# ### Seaborn Datasets

# %%
#Seaborn is a library for making statistical graphics in Python.

# %%
import seaborn as sb

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic = sb.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
diamonds =sb.load_dataset('diamonds')

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 51811   0.71      Ideal     F     SI1   61.6   56.0   2416  5.71  5.75  3.53
# 51812   1.01      Ideal     I      I1   61.6   56.0   2416  6.45  6.43  3.97
# 51813   0.70      Ideal     I     SI1   62.8   56.0   2417  5.63  5.68  3.55
# 51814   0.76  Very Good     H     SI2   59.8   58.0   2418  5.94  5.96  3.56
# 51815   0.72    Premium     H     VS2   61.6   57.0   2418  5.84  5.78  3.50
#
# [51816 rows x 10 columns]

# %%
tips =sb.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Read Excel files

# %%
#Import Data from Excel file
#pip install xlrd
#pip install --upgrade xlrd
#pip install openpyxl
#import xlrd
#import pandas as pd

# %%
orders = pd.read_excel('data/Orders.xlsx')
orders
# Out:
#      OrderID CustomerID  EmployeeID  OrderDate RequiredDate ShippedDate
# 0      10248      VINET           5 1996-07-04   1996-08-01  1996-07-16  \
# 1      10249      TOMSP           6 1996-07-05   1996-08-16  1996-07-10
# 2      10250      HANAR           4 1996-07-08   1996-08-05  1996-07-12
# 3      10251      VICTE           3 1996-07-08   1996-08-05  1996-07-15
# 4      10252      SUPRD           4 1996-07-09   1996-08-06  1996-07-11
# ..       ...        ...         ...        ...          ...         ...
# 825    11073      PERIC           2 1998-05-05   1998-06-02         NaT
# 826    11074      SIMOB           7 1998-05-06   1998-06-03         NaT
# 827    11075      RICSU           8 1998-05-06   1998-06-03         NaT
# 828    11076      BONAP           4 1998-05-06   1998-06-03         NaT
# 829    11077      RATTC           1 1998-05-06   1998-06-03         NaT
#
#      ShipVia  Freight                    ShipName               ShipAddress
# ...

# %% [markdown]
# ### Connection to database mssql

# %%
#pip install pyodbc
#pip install SQLAlchemy
#import pyodbc
#con = pyodbc.connect(
#  host ="localhost",
#  user = "yourusername",
#  password = "yourpassword",
#  database ="mydatabase"
#)

# %%
import pyodbc
  
conn =pyodbc.connect('Driver={SQL Server Native Client 11.0};'
                     'Server=localhost;'
                     'Database=Northwind;'
                     'Trusted_Connection=yes;')

# %%
df = pd.read_sql("select * from Products",conn)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_41616\500196871.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("select * from Products",conn)

# %%
df
# Out:
#     ProductID                      ProductName  SupplierID  CategoryID
# 0           1                             Chai           1           1  \
# 1           2                            Chang           1           1
# 2           3                    Aniseed Syrup           1           2
# 3           4     Chef Anton's Cajun Seasoning           2           2
# 4           5           Chef Anton's Gumbo Mix           2           2
# ..        ...                              ...         ...         ...
# 72         73                       R?d Kaviar          17           8
# 73         74                    Longlife Tofu           4           7
# 74         75             Rh?nbr?u Klosterbier          12           1
# 75         76                     Lakkalik??ri          23           1
# 76         77  Original Frankfurter gr?ne So?e          12           2
#
#         QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel
# ...

# %% [markdown]
# ## General information

# %%
#df.shape
#df.head()
#df.tail()
#df.info()
#df.describe()

# %%
products
# Out:
#     ProductID                      ProductName  UnitPrice  CategoryID
# 0           1                             Chai      18.00           1
# 1           2                            Chang      19.00           1
# 2           3                    Aniseed Syrup      10.00           2
# 3           4     Chef Anton's Cajun Seasoning      22.00           2
# 4           5           Chef Anton's Gumbo Mix      21.35           2
# ..        ...                              ...        ...         ...
# 72         73                       Rad Kaviar      15.00           8
# 73         74                    Longlife Tofu      10.00           7
# 74         75             Rhanbrau Klosterbier       7.75           1
# 75         76                     Lakkalikaari      18.00           1
# 76         77  Original Frankfurter grane Soae      13.00           2
#
# [77 rows x 4 columns]

# %%
products.columns
# Out:
# Index(['ProductID', 'ProductName', 'UnitPrice', 'CategoryID'], dtype='object')

# %%
products.values
# Out:
# array([[1, 'Chai', 18.0, 1],
#        [2, 'Chang', 19.0, 1],
#        [3, 'Aniseed Syrup', 10.0, 2],
#        [4, "Chef Anton's Cajun Seasoning", 22.0, 2],
#        [5, "Chef Anton's Gumbo Mix", 21.35, 2],
#        [6, "Grandma's Boysenberry Spread", 25.0, 2],
#        [7, "Uncle Bob's Organic Dried Pears", 30.0, 7],
#        [8, 'Northwoods Cranberry Sauce', 40.0, 2],
#        [9, 'Mishi Kobe Niku', 97.0, 6],
#        [10, 'Ikura', 31.0, 8],
#        [11, 'Queso Cabrales', 21.0, 4],
#        [12, 'Queso Manchego La Pastora', 38.0, 4],
#        [13, 'Konbu', 6.0, 8],
#        [14, 'Tofu', 23.25, 7],
#        [15, 'Genen Shouyu', 15.5, 2],
#        [16, 'Pavlova', 17.45, 3],
#        [17, 'Alice Mutton', 39.0, 6],
#        [18, 'Carnarvon Tigers', 62.5, 8],
#        [19, 'Teatime Chocolate Biscuits', 9.2, 3],
#        [20, "Sir Rodney's Marmalade", 81.0, 3],
#        [21, "Sir Rodney's Scones", 10.0, 3],
#        [22, "Gustaf's Knackebrad", 21.0, 5],
# ...

# %%
products.shape
# Out:
# (77, 4)

# %%
len(products)
# Out:
# 77

# %%
#columns* rows
products.size
# Out:
# 308

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    77 non-null     int64
#  1   ProductName  77 non-null     object
#  2   UnitPrice    77 non-null     float64
#  3   CategoryID   77 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 2.5+ KB

# %%
products.head()
# Out:
#    ProductID                   ProductName  UnitPrice  CategoryID
# 0          1                          Chai      18.00           1
# 1          2                         Chang      19.00           1
# 2          3                 Aniseed Syrup      10.00           2
# 3          4  Chef Anton's Cajun Seasoning      22.00           2
# 4          5        Chef Anton's Gumbo Mix      21.35           2

# %%
products.head(10)
# Out:
#    ProductID                      ProductName  UnitPrice  CategoryID
# 0          1                             Chai      18.00           1
# 1          2                            Chang      19.00           1
# 2          3                    Aniseed Syrup      10.00           2
# 3          4     Chef Anton's Cajun Seasoning      22.00           2
# 4          5           Chef Anton's Gumbo Mix      21.35           2
# 5          6     Grandma's Boysenberry Spread      25.00           2
# 6          7  Uncle Bob's Organic Dried Pears      30.00           7
# 7          8       Northwoods Cranberry Sauce      40.00           2
# 8          9                  Mishi Kobe Niku      97.00           6
# 9         10                            Ikura      31.00           8

# %%
products.tail(5)
# Out:
#     ProductID                      ProductName  UnitPrice  CategoryID
# 72         73                       Rad Kaviar      15.00           8
# 73         74                    Longlife Tofu      10.00           7
# 74         75             Rhanbrau Klosterbier       7.75           1
# 75         76                     Lakkalikaari      18.00           1
# 76         77  Original Frankfurter grane Soae      13.00           2

# %%
products.describe()
# Out:
#        ProductID   UnitPrice  CategoryID
# count  77.000000   77.000000   77.000000
# mean   39.000000   28.866364    4.116883
# std    22.371857   33.815111    2.395028
# min     1.000000    2.500000    1.000000
# 25%    20.000000   13.250000    2.000000
# 50%    39.000000   19.500000    4.000000
# 75%    58.000000   33.250000    6.000000
# max    77.000000  263.500000    8.000000

# %% [markdown]
# ### Display specific columns

# %%
#2 Options to select columns
#df.column
#df['column']

# %%
products
# Out:
#     ProductID                      ProductName  UnitPrice  CategoryID
# 0           1                             Chai      18.00           1
# 1           2                            Chang      19.00           1
# 2           3                    Aniseed Syrup      10.00           2
# 3           4     Chef Anton's Cajun Seasoning      22.00           2
# 4           5           Chef Anton's Gumbo Mix      21.35           2
# ..        ...                              ...        ...         ...
# 72         73                       Rad Kaviar      15.00           8
# 73         74                    Longlife Tofu      10.00           7
# 74         75             Rhanbrau Klosterbier       7.75           1
# 75         76                     Lakkalikaari      18.00           1
# 76         77  Original Frankfurter grane Soae      13.00           2
#
# [77 rows x 4 columns]

# %%
products["ProductName"]
# Out:
# 0                                Chai
# 1                               Chang
# 2                       Aniseed Syrup
# 3        Chef Anton's Cajun Seasoning
# 4              Chef Anton's Gumbo Mix
#                    ...
# 72                         Rad Kaviar
# 73                      Longlife Tofu
# 74               Rhanbrau Klosterbier
# 75                       Lakkalikaari
# 76    Original Frankfurter grane Soae
# Name: ProductName, Length: 77, dtype: object

# %%
products.UnitPrice
# Out:
# 0     18.00
# 1     19.00
# 2     10.00
# 3     22.00
# 4     21.35
#       ...
# 72    15.00
# 73    10.00
# 74     7.75
# 75    18.00
# 76    13.00
# Name: UnitPrice, Length: 77, dtype: float64

# %%
price =products.UnitPrice

# %%
price
# Out:
# 0     18.00
# 1     19.00
# 2     10.00
# 3     22.00
# 4     21.35
#       ...
# 72    15.00
# 73    10.00
# 74     7.75
# 75    18.00
# 76    13.00
# Name: UnitPrice, Length: 77, dtype: float64

# %%
#series 
type(price)
# Out:
# pandas.core.series.Series

# %%
price.head()
# Out:
# 0    18.00
# 1    19.00
# 2    10.00
# 3    22.00
# 4    21.35
# Name: UnitPrice, dtype: float64

# %%
price.shape
# Out:
# (77,)

# %%
price.values
# Out:
# array([ 18.  ,  19.  ,  10.  ,  22.  ,  21.35,  25.  ,  30.  ,  40.  ,
#         97.  ,  31.  ,  21.  ,  38.  ,   6.  ,  23.25,  15.5 ,  17.45,
#         39.  ,  62.5 ,   9.2 ,  81.  ,  10.  ,  21.  ,   9.  ,   4.5 ,
#         14.  ,  31.23,  43.9 ,  45.6 , 123.79,  25.89,  12.5 ,  32.  ,
#          2.5 ,  14.  ,  18.  ,  19.  ,  26.  , 263.5 ,  18.  ,  18.4 ,
#          9.65,  14.  ,  46.  ,  19.45,   9.5 ,  12.  ,   9.5 ,  12.75,
#         20.  ,  16.25,  53.  ,   7.  ,  32.8 ,   7.45,  24.  ,  38.  ,
#         19.5 ,  13.25,  55.  ,  34.  ,  28.5 ,  49.3 ,  43.9 ,  33.25,
#         21.05,  17.  ,  14.  ,  12.5 ,  36.  ,  15.  ,  21.5 ,  34.8 ,
#         15.  ,  10.  ,   7.75,  18.  ,  13.  ])

# %%
price.describe()
# Out:
# count     77.000000
# mean      28.866364
# std       33.815111
# min        2.500000
# 25%       13.250000
# 50%       19.500000
# 75%       33.250000
# max      263.500000
# Name: UnitPrice, dtype: float64

# %%
products.head()
# Out:
#    ProductID                   ProductName  UnitPrice  CategoryID
# 0          1                          Chai      18.00           1
# 1          2                         Chang      19.00           1
# 2          3                 Aniseed Syrup      10.00           2
# 3          4  Chef Anton's Cajun Seasoning      22.00           2
# 4          5        Chef Anton's Gumbo Mix      21.35           2

# %%
products["ProductName"].head()
# Out:
# 0                            Chai
# 1                           Chang
# 2                   Aniseed Syrup
# 3    Chef Anton's Cajun Seasoning
# 4          Chef Anton's Gumbo Mix
# Name: ProductName, dtype: object

# %%
products["ProductName"].describe()
# Out:
# count       77
# unique      77
# top       Chai
# freq         1
# Name: ProductName, dtype: object

# %%
type(products["ProductName"])
# Out:
# pandas.core.series.Series

# %%
#df[["column","column2",...]]

# %%
products[["ProductName","UnitPrice"]].head()
# Out:
#                     ProductName  UnitPrice
# 0                          Chai      18.00
# 1                         Chang      19.00
# 2                 Aniseed Syrup      10.00
# 3  Chef Anton's Cajun Seasoning      22.00
# 4        Chef Anton's Gumbo Mix      21.35

# %%
type(products)
# Out:
# pandas.core.frame.DataFrame

# %%
lst= ["ProductName","UnitPrice"]

# %%
type(lst)
# Out:
# list

# %%
products["ProductName"]
# Out:
# 0                                Chai
# 1                               Chang
# 2                       Aniseed Syrup
# 3        Chef Anton's Cajun Seasoning
# 4              Chef Anton's Gumbo Mix
#                    ...
# 72                         Rad Kaviar
# 73                      Longlife Tofu
# 74               Rhanbrau Klosterbier
# 75                       Lakkalikaari
# 76    Original Frankfurter grane Soae
# Name: ProductName, Length: 77, dtype: object

# %%
products[["ProductName","UnitPrice"]]
# Out:
#                         ProductName  UnitPrice
# 0                              Chai      18.00
# 1                             Chang      19.00
# 2                     Aniseed Syrup      10.00
# 3      Chef Anton's Cajun Seasoning      22.00
# 4            Chef Anton's Gumbo Mix      21.35
# ..                              ...        ...
# 72                       Rad Kaviar      15.00
# 73                    Longlife Tofu      10.00
# 74             Rhanbrau Klosterbier       7.75
# 75                     Lakkalikaari      18.00
# 76  Original Frankfurter grane Soae      13.00
#
# [77 rows x 2 columns]

# %%
products[lst]
# Out:
#                         ProductName  UnitPrice
# 0                              Chai      18.00
# 1                             Chang      19.00
# 2                     Aniseed Syrup      10.00
# 3      Chef Anton's Cajun Seasoning      22.00
# 4            Chef Anton's Gumbo Mix      21.35
# ..                              ...        ...
# 72                       Rad Kaviar      15.00
# 73                    Longlife Tofu      10.00
# 74             Rhanbrau Klosterbier       7.75
# 75                     Lakkalikaari      18.00
# 76  Original Frankfurter grane Soae      13.00
#
# [77 rows x 2 columns]

# %%
type(products["ProductName"].head())
# Out:
# pandas.core.series.Series

# %%
#to_frame --Convert Series to DataFrame.
# or use [[]]
# DataFrame objects can have different data types. 
#Series --– All elements must be of same data type.

# %%
products["ProductName"]
# Out:
# 0                                Chai
# 1                               Chang
# 2                       Aniseed Syrup
# 3        Chef Anton's Cajun Seasoning
# 4              Chef Anton's Gumbo Mix
#                    ...
# 72                         Rad Kaviar
# 73                      Longlife Tofu
# 74               Rhanbrau Klosterbier
# 75                       Lakkalikaari
# 76    Original Frankfurter grane Soae
# Name: ProductName, Length: 77, dtype: object

# %%
products["ProductName"].to_frame()
# Out:
#                         ProductName
# 0                              Chai
# 1                             Chang
# 2                     Aniseed Syrup
# 3      Chef Anton's Cajun Seasoning
# 4            Chef Anton's Gumbo Mix
# ..                              ...
# 72                       Rad Kaviar
# 73                    Longlife Tofu
# 74             Rhanbrau Klosterbier
# 75                     Lakkalikaari
# 76  Original Frankfurter grane Soae
#
# [77 rows x 1 columns]

# %%
type(products["ProductName"].to_frame().head())
# Out:
# pandas.core.frame.DataFrame

# %%
products["ProductName"].to_frame().head()
# Out:
#                     ProductName
# 0                          Chai
# 1                         Chang
# 2                 Aniseed Syrup
# 3  Chef Anton's Cajun Seasoning
# 4        Chef Anton's Gumbo Mix

# %%
products["ProductName"].head().to_frame()
# Out:
#                     ProductName
# 0                          Chai
# 1                         Chang
# 2                 Aniseed Syrup
# 3  Chef Anton's Cajun Seasoning
# 4        Chef Anton's Gumbo Mix

# %%
products[["ProductName"]].head()
# Out:
#                     ProductName
# 0                          Chai
# 1                         Chang
# 2                 Aniseed Syrup
# 3  Chef Anton's Cajun Seasoning
# 4        Chef Anton's Gumbo Mix

# %%
type(products[["ProductName"]].head())
# Out:
# pandas.core.frame.DataFrame

# %%
type(products[["UnitPrice"]].head())
# Out:
# pandas.core.frame.DataFrame

# %%
#Calculation -- + - * /

# %%
products[["UnitPrice"]]+10
# Out:
#     UnitPrice
# 0       28.00
# 1       29.00
# 2       20.00
# 3       32.00
# 4       31.35
# ..        ...
# 72      25.00
# 73      20.00
# 74      17.75
# 75      28.00
# 76      23.00
#
# [77 rows x 1 columns]

# %%
products[["UnitPrice"]].head(5)+10
# Out:
#    UnitPrice
# 0      28.00
# 1      29.00
# 2      20.00
# 3      32.00
# 4      31.35

# %%
products[["UnitPrice"]].head(5)-10
# Out:
#    UnitPrice
# 0       8.00
# 1       9.00
# 2       0.00
# 3      12.00
# 4      11.35

# %%
products[["UnitPrice"]].head(5)*1.17
# Out:
#    UnitPrice
# 0    21.0600
# 1    22.2300
# 2    11.7000
# 3    25.7400
# 4    24.9795

# %%
products[["UnitPrice"]].head(5)/2
# Out:
#    UnitPrice
# 0      9.000
# 1      9.500
# 2      5.000
# 3     11.000
# 4     10.675

# %%
products.columns
# Out:
# Index(['ProductID', 'ProductName', 'UnitPrice', 'CategoryID'], dtype='object')

# %%
column = ["ProductID","ProductName","UnitPrice"]
products[column].head()
# Out:
#    ProductID                   ProductName  UnitPrice
# 0          1                          Chai      18.00
# 1          2                         Chang      19.00
# 2          3                 Aniseed Syrup      10.00
# 3          4  Chef Anton's Cajun Seasoning      22.00
# 4          5        Chef Anton's Gumbo Mix      21.35

# %%
products
# Out:
#     ProductID                      ProductName  UnitPrice  CategoryID
# 0           1                             Chai      18.00           1
# 1           2                            Chang      19.00           1
# 2           3                    Aniseed Syrup      10.00           2
# 3           4     Chef Anton's Cajun Seasoning      22.00           2
# 4           5           Chef Anton's Gumbo Mix      21.35           2
# ..        ...                              ...        ...         ...
# 72         73                       Rad Kaviar      15.00           8
# 73         74                    Longlife Tofu      10.00           7
# 74         75             Rhanbrau Klosterbier       7.75           1
# 75         76                     Lakkalikaari      18.00           1
# 76         77  Original Frankfurter grane Soae      13.00           2
#
# [77 rows x 4 columns]

# %% [markdown]
# ### Concatenation

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    77 non-null     int64
#  1   ProductName  77 non-null     object
#  2   UnitPrice    77 non-null     float64
#  3   CategoryID   77 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 2.5+ KB

# %%
products["ProductName"]+' '+products["UnitPrice"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File C:\Python311\Lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File C:\Python311\Lib\site-packages\pandas\core\computation\expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: can only concatenate str (not "float") to str
#
# ...

# %%
products["ProductName"].head(5)+' '+str(products["UnitPrice"].head(5))
# Out:
# 0    Chai 0    18.00\n1    19.00\n2    10.00\n3    ...
# 1    Chang 0    18.00\n1    19.00\n2    10.00\n3   ...
# 2    Aniseed Syrup 0    18.00\n1    19.00\n2    10....
# 3    Chef Anton's Cajun Seasoning 0    18.00\n1    ...
# 4    Chef Anton's Gumbo Mix 0    18.00\n1    19.00\...
# Name: ProductName, dtype: object

# %%
type(a)
# Out:
# list

# %%
df = pd.read_sql("select LastName,FirstName from Employees",conn)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_41616\2241467003.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("select LastName,FirstName from Employees",conn)

# %%
df
# Out:
#     LastName FirstName
# 0    Davolio     Nancy
# 1     Fuller    Andrew
# 2  Leverling     Janet
# 3    Peacock  Margaret
# 4   Buchanan    Steven
# 5     Suyama   Michael
# 6       King    Robert
# 7   Callahan     Laura
# 8  Dodsworth      Anne

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[["LastName","FirstName"]].head(3)
# Out:
#     LastName FirstName
# 0    Davolio     Nancy
# 1     Fuller    Andrew
# 2  Leverling     Janet

# %%
df["LastName"]+' '+df["FirstName"]
# Out:
# 0       Davolio Nancy
# 1       Fuller Andrew
# 2     Leverling Janet
# 3    Peacock Margaret
# 4     Buchanan Steven
# 5      Suyama Michael
# 6         King Robert
# 7      Callahan Laura
# 8      Dodsworth Anne
# dtype: object

# %%
df["LastName"].head(3)+' '+df["FirstName"].head(3)
# Out:
# 0      Davolio Nancy
# 1      Fuller Andrew
# 2    Leverling Janet
# dtype: object

# %% [markdown]
# ### Rename Columns

# %%
# * List =   [] read/write
# * Tuples = () read only
# * Dictionaries{key:value,key:value}

# %%
df[["LastName","FirstName"]].rename(columns = {"LastName":"LName","FirstName":"FName"})
# Out:
#        LName     FName
# 0    Davolio     Nancy
# 1     Fuller    Andrew
# 2  Leverling     Janet
# 3    Peacock  Margaret
# 4   Buchanan    Steven
# 5     Suyama   Michael
# 6       King    Robert
# 7   Callahan     Laura
# 8  Dodsworth      Anne

# %% [markdown]
# ### Distinct ---drop_duplicates

# %%
df_loc = pd.read_sql("select Country, City from employees",conn)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_41616\4279164344.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_loc = pd.read_sql("select Country, City from employees",conn)

# %%
pd.read_sql("select Country, City from employees",conn).head().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  5 non-null      object
#  1   City     5 non-null      object
# dtypes: object(2)
# memory usage: 212.0+ bytes
# C:\Users\jbt\AppData\Local\Temp\ipykernel_41616\645852166.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select Country, City from employees",conn).head().info()

# %%
df_loc
# Out:
#   Country      City
# 0     USA   Seattle
# 1     USA    Tacoma
# 2     USA  Kirkland
# 3     USA   Redmond
# 4      UK    London
# 5      UK    London
# 6      UK    London
# 7     USA   Seattle
# 8      UK    London

# %%
df_loc.drop_duplicates()
# Out:
#   Country      City
# 0     USA   Seattle
# 1     USA    Tacoma
# 2     USA  Kirkland
# 3     USA   Redmond
# 4      UK    London

# %%
df_loc[["Country"]].drop_duplicates()
# Out:
#   Country
# 0     USA
# 4      UK

# %%
df_loc
# Out:
#   Country      City
# 0     USA   Seattle
# 1     USA    Tacoma
# 2     USA  Kirkland
# 3     USA   Redmond
# 4      UK    London
# 5      UK    London
# 6      UK    London
# 7     USA   Seattle
# 8      UK    London

# %%
df_loc["Country"].drop_duplicates()
# Out:
# 0    USA
# 4     UK
# Name: Country, dtype: object

# %% [markdown]
# ### Add New column

# %%
products.head(5)
# Out:
#    ProductID                   ProductName  UnitPrice  CategoryID
# 0          1                          Chai      18.00           1
# 1          2                         Chang      19.00           1
# 2          3                 Aniseed Syrup      10.00           2
# 3          4  Chef Anton's Cajun Seasoning      22.00           2
# 4          5        Chef Anton's Gumbo Mix      21.35           2

# %%
products["After Tax"] = products["UnitPrice"]*1.17

# %%
products.head()
# Out:
#    ProductID                   ProductName  UnitPrice  CategoryID  After Tax
# 0          1                          Chai      18.00           1    21.0600
# 1          2                         Chang      19.00           1    22.2300
# 2          3                 Aniseed Syrup      10.00           2    11.7000
# 3          4  Chef Anton's Cajun Seasoning      22.00           2    25.7400
# 4          5        Chef Anton's Gumbo Mix      21.35           2    24.9795

# %%
products["After Tax"] =products["After Tax"] +10

# %%
products.head()
# Out:
#    ProductID                   ProductName  UnitPrice  CategoryID  After Tax
# 0          1                          Chai      18.00           1    31.0600
# 1          2                         Chang      19.00           1    32.2300
# 2          3                 Aniseed Syrup      10.00           2    21.7000
# 3          4  Chef Anton's Cajun Seasoning      22.00           2    35.7400
# 4          5        Chef Anton's Gumbo Mix      21.35           2    34.9795

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    77 non-null     int64
#  1   ProductName  77 non-null     object
#  2   UnitPrice    77 non-null     float64
#  3   CategoryID   77 non-null     int64
#  4   After Tax    77 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 3.1+ KB

# %%
products.assign(Total=products["UnitPrice"]*1.17).head(5)
# Out:
#    ProductID                   ProductName  UnitPrice  CategoryID  After Tax
# 0          1                          Chai      18.00           1    31.0600  \
# 1          2                         Chang      19.00           1    32.2300
# 2          3                 Aniseed Syrup      10.00           2    21.7000
# 3          4  Chef Anton's Cajun Seasoning      22.00           2    35.7400
# 4          5        Chef Anton's Gumbo Mix      21.35           2    34.9795
#
#      Total
# 0  21.0600
# 1  22.2300
# 2  11.7000
# 3  25.7400
# 4  24.9795

# %%
products.head()
# Out:
#    ProductID                   ProductName  UnitPrice  CategoryID  After Tax
# 0          1                          Chai      18.00           1    31.0600
# 1          2                         Chang      19.00           1    32.2300
# 2          3                 Aniseed Syrup      10.00           2    21.7000
# 3          4  Chef Anton's Cajun Seasoning      22.00           2    35.7400
# 4          5        Chef Anton's Gumbo Mix      21.35           2    34.9795

# %% [markdown]
# ### Add column to specific location

# %%
products.insert(3,'Total',products["UnitPrice"]*1.17)

# %%
products
# Out:
#     ProductID                      ProductName  UnitPrice    Total
# 0           1                             Chai      18.00  21.0600  \
# 1           2                            Chang      19.00  22.2300
# 2           3                    Aniseed Syrup      10.00  11.7000
# 3           4     Chef Anton's Cajun Seasoning      22.00  25.7400
# 4           5           Chef Anton's Gumbo Mix      21.35  24.9795
# ..        ...                              ...        ...      ...
# 72         73                       Rad Kaviar      15.00  17.5500
# 73         74                    Longlife Tofu      10.00  11.7000
# 74         75             Rhanbrau Klosterbier       7.75   9.0675
# 75         76                     Lakkalikaari      18.00  21.0600
# 76         77  Original Frankfurter grane Soae      13.00  15.2100
#
#     CategoryID  After Tax
# 0            1    31.0600
# 1            1    32.2300
# 2            2    21.7000
# 3            2    35.7400
# ...

# %%
products.assign(Discount=products["UnitPrice"]*0.1,
                 AfterDiscount=products["UnitPrice"]-products["UnitPrice"]*0.1)
# Out:
#     ProductID                      ProductName  UnitPrice    Total
# 0           1                             Chai      18.00  21.0600  \
# 1           2                            Chang      19.00  22.2300
# 2           3                    Aniseed Syrup      10.00  11.7000
# 3           4     Chef Anton's Cajun Seasoning      22.00  25.7400
# 4           5           Chef Anton's Gumbo Mix      21.35  24.9795
# ..        ...                              ...        ...      ...
# 72         73                       Rad Kaviar      15.00  17.5500
# 73         74                    Longlife Tofu      10.00  11.7000
# 74         75             Rhanbrau Klosterbier       7.75   9.0675
# 75         76                     Lakkalikaari      18.00  21.0600
# 76         77  Original Frankfurter grane Soae      13.00  15.2100
#
#     CategoryID  After Tax  Discount  AfterDiscount
# 0            1    31.0600     1.800         16.200
# 1            1    32.2300     1.900         17.100
# ...

# %%
products
# Out:
#     ProductID                      ProductName  UnitPrice    Total
# 0           1                             Chai      18.00  21.0600  \
# 1           2                            Chang      19.00  22.2300
# 2           3                    Aniseed Syrup      10.00  11.7000
# 3           4     Chef Anton's Cajun Seasoning      22.00  25.7400
# 4           5           Chef Anton's Gumbo Mix      21.35  24.9795
# ..        ...                              ...        ...      ...
# 72         73                       Rad Kaviar      15.00  17.5500
# 73         74                    Longlife Tofu      10.00  11.7000
# 74         75             Rhanbrau Klosterbier       7.75   9.0675
# 75         76                     Lakkalikaari      18.00  21.0600
# 76         77  Original Frankfurter grane Soae      13.00  15.2100
#
#     CategoryID  After Tax
# 0            1    31.0600
# 1            1    32.2300
# 2            2    21.7000
# 3            2    35.7400
# ...

# %%
pro=products[["ProductID","ProductName","UnitPrice","After Tax"]]

# %%
pro
# Out:
#     ProductID                      ProductName  UnitPrice  After Tax
# 0           1                             Chai      18.00    31.0600
# 1           2                            Chang      19.00    32.2300
# 2           3                    Aniseed Syrup      10.00    21.7000
# 3           4     Chef Anton's Cajun Seasoning      22.00    35.7400
# 4           5           Chef Anton's Gumbo Mix      21.35    34.9795
# ..        ...                              ...        ...        ...
# 72         73                       Rad Kaviar      15.00    27.5500
# 73         74                    Longlife Tofu      10.00    21.7000
# 74         75             Rhanbrau Klosterbier       7.75    19.0675
# 75         76                     Lakkalikaari      18.00    31.0600
# 76         77  Original Frankfurter grane Soae      13.00    25.2100
#
# [77 rows x 4 columns]

# %%
products.drop(columns ="Total")
# Out:
#     ProductID                      ProductName  UnitPrice  CategoryID
# 0           1                             Chai      18.00           1  \
# 1           2                            Chang      19.00           1
# 2           3                    Aniseed Syrup      10.00           2
# 3           4     Chef Anton's Cajun Seasoning      22.00           2
# 4           5           Chef Anton's Gumbo Mix      21.35           2
# ..        ...                              ...        ...         ...
# 72         73                       Rad Kaviar      15.00           8
# 73         74                    Longlife Tofu      10.00           7
# 74         75             Rhanbrau Klosterbier       7.75           1
# 75         76                     Lakkalikaari      18.00           1
# 76         77  Original Frankfurter grane Soae      13.00           2
#
#     After Tax
# 0     31.0600
# 1     32.2300
# 2     21.7000
# 3     35.7400
# 4     34.9795
# ..        ...
# 72    27.5500
# ...

# %%
products
# Out:
#     ProductID                      ProductName  UnitPrice    Total
# 0           1                             Chai      18.00  21.0600  \
# 1           2                            Chang      19.00  22.2300
# 2           3                    Aniseed Syrup      10.00  11.7000
# 3           4     Chef Anton's Cajun Seasoning      22.00  25.7400
# 4           5           Chef Anton's Gumbo Mix      21.35  24.9795
# ..        ...                              ...        ...      ...
# 72         73                       Rad Kaviar      15.00  17.5500
# 73         74                    Longlife Tofu      10.00  11.7000
# 74         75             Rhanbrau Klosterbier       7.75   9.0675
# 75         76                     Lakkalikaari      18.00  21.0600
# 76         77  Original Frankfurter grane Soae      13.00  15.2100
#
#     CategoryID  After Tax
# 0            1    31.0600
# 1            1    32.2300
# 2            2    21.7000
# 3            2    35.7400
# ...

# %%
products.drop(["Total"],axis=1)
# Out:
#     ProductID                      ProductName  UnitPrice  CategoryID
# 0           1                             Chai      18.00           1  \
# 1           2                            Chang      19.00           1
# 2           3                    Aniseed Syrup      10.00           2
# 3           4     Chef Anton's Cajun Seasoning      22.00           2
# 4           5           Chef Anton's Gumbo Mix      21.35           2
# ..        ...                              ...        ...         ...
# 72         73                       Rad Kaviar      15.00           8
# 73         74                    Longlife Tofu      10.00           7
# 74         75             Rhanbrau Klosterbier       7.75           1
# 75         76                     Lakkalikaari      18.00           1
# 76         77  Original Frankfurter grane Soae      13.00           2
#
#     After Tax
# 0     31.0600
# 1     32.2300
# 2     21.7000
# 3     35.7400
# 4     34.9795
# ..        ...
# 72    27.5500
# ...

# %%
products
# Out:
#     ProductID                      ProductName  UnitPrice    Total
# 0           1                             Chai      18.00  21.0600  \
# 1           2                            Chang      19.00  22.2300
# 2           3                    Aniseed Syrup      10.00  11.7000
# 3           4     Chef Anton's Cajun Seasoning      22.00  25.7400
# 4           5           Chef Anton's Gumbo Mix      21.35  24.9795
# ..        ...                              ...        ...      ...
# 72         73                       Rad Kaviar      15.00  17.5500
# 73         74                    Longlife Tofu      10.00  11.7000
# 74         75             Rhanbrau Klosterbier       7.75   9.0675
# 75         76                     Lakkalikaari      18.00  21.0600
# 76         77  Original Frankfurter grane Soae      13.00  15.2100
#
#     CategoryID  After Tax
# 0            1    31.0600
# 1            1    32.2300
# 2            2    21.7000
# 3            2    35.7400
# ...

# %% [markdown]
# ### pop out a column from the dataframe

# %%
#Return item and drop from frame.
products.pop("Total")
# Out:
# 0     21.0600
# 1     22.2300
# 2     11.7000
# 3     25.7400
# 4     24.9795
#        ...
# 72    17.5500
# 73    11.7000
# 74     9.0675
# 75    21.0600
# 76    15.2100
# Name: Total, Length: 77, dtype: float64

# %%
products
# Out:
#     ProductID                      ProductName  UnitPrice  CategoryID
# 0           1                             Chai      18.00           1  \
# 1           2                            Chang      19.00           1
# 2           3                    Aniseed Syrup      10.00           2
# 3           4     Chef Anton's Cajun Seasoning      22.00           2
# 4           5           Chef Anton's Gumbo Mix      21.35           2
# ..        ...                              ...        ...         ...
# 72         73                       Rad Kaviar      15.00           8
# 73         74                    Longlife Tofu      10.00           7
# 74         75             Rhanbrau Klosterbier       7.75           1
# 75         76                     Lakkalikaari      18.00           1
# 76         77  Original Frankfurter grane Soae      13.00           2
#
#     After Tax
# 0     31.0600
# 1     32.2300
# 2     21.7000
# 3     35.7400
# 4     34.9795
# ..        ...
# 72    27.5500
# ...

# %%
products.head()
# Out:
#    ProductID                   ProductName  UnitPrice  CategoryID  After Tax
# 0          1                          Chai      18.00           1    31.0600
# 1          2                         Chang      19.00           1    32.2300
# 2          3                 Aniseed Syrup      10.00           2    21.7000
# 3          4  Chef Anton's Cajun Seasoning      22.00           2    35.7400
# 4          5        Chef Anton's Gumbo Mix      21.35           2    34.9795

# %%
products["Total"]=products["UnitPrice"]*1.17

# %%
products
# Out:
#     ProductID                      ProductName  UnitPrice  CategoryID
# 0           1                             Chai      18.00           1  \
# 1           2                            Chang      19.00           1
# 2           3                    Aniseed Syrup      10.00           2
# 3           4     Chef Anton's Cajun Seasoning      22.00           2
# 4           5           Chef Anton's Gumbo Mix      21.35           2
# ..        ...                              ...        ...         ...
# 72         73                       Rad Kaviar      15.00           8
# 73         74                    Longlife Tofu      10.00           7
# 74         75             Rhanbrau Klosterbier       7.75           1
# 75         76                     Lakkalikaari      18.00           1
# 76         77  Original Frankfurter grane Soae      13.00           2
#
#     After Tax    Total
# 0     31.0600  21.0600
# 1     32.2300  22.2300
# 2     21.7000  11.7000
# 3     35.7400  25.7400
# ...

# %%
pop_total = products.pop("Total")

# %%
pop_total
# Out:
# 0     21.0600
# 1     22.2300
# 2     11.7000
# 3     25.7400
# 4     24.9795
#        ...
# 72    17.5500
# 73    11.7000
# 74     9.0675
# 75    21.0600
# 76    15.2100
# Name: Total, Length: 77, dtype: float64

# %%
products["Total"]=products["UnitPrice"]*1.17

# %%
del products["Total"]

# %%
del products

# %%
products
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[260], line 1
# ----> 1 products
#
# NameError: name 'products' is not defined

# %%
products.head()
# Out:
#    ProductID                   ProductName  UnitPrice  CategoryID  After Tax
# 0          1                          Chai      18.00           1    31.0600
# 1          2                         Chang      19.00           1    32.2300
# 2          3                 Aniseed Syrup      10.00           2    21.7000
# 3          4  Chef Anton's Cajun Seasoning      22.00           2    35.7400
# 4          5        Chef Anton's Gumbo Mix      21.35           2    34.9795

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#pandas.DataFrame.drop

# %%
#Remove rows or columns by specifying label names and corresponding axis, or by specifying directly index or column names.
drop_row=titanic.drop(0)

# %%
drop_row
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 1           1       1  female  38.0      1      0  71.2833        C   First  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#axis = 1 or columns
drop_col=titanic.drop(labels="deck",axis=1)

# %%
drop_col
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
drop_col=titanic.drop(labels=["deck","who","embarked"],axis="columns")

# %%
drop_col
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare   class
# 0           0       3    male  22.0      1      0   7.2500   Third  \
# 1           1       1  female  38.0      1      0  71.2833   First
# 2           1       3  female  26.0      0      0   7.9250   Third
# 3           1       1  female  35.0      1      0  53.1000   First
# 4           0       3    male  35.0      0      0   8.0500   Third
# ..        ...     ...     ...   ...    ...    ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000  Second
# 887         1       1  female  19.0      0      0  30.0000   First
# 888         0       3  female   NaN      1      2  23.4500   Third
# 889         1       1    male  26.0      0      0  30.0000   First
# 890         0       3    male  32.0      0      0   7.7500   Third
#
#      adult_male  embark_town alive  alone
# 0          True  Southampton    no  False
# 1         False    Cherbourg   yes  False
# ...

# %%
#To cahnge original dataframe

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.drop(labels="deck",axis=1, inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
#short way drop columns

# %%
titanic.drop(columns=["sibsp","parch","who"])
# Out:
#      survived  pclass     sex   age     fare embarked   class  adult_male
# 0           0       3    male  22.0   7.2500        S   Third        True  \
# 1           1       1  female  38.0  71.2833        C   First       False
# 2           1       3  female  26.0   7.9250        S   Third       False
# 3           1       1  female  35.0  53.1000        S   First       False
# 4           0       3    male  35.0   8.0500        S   Third        True
# ..        ...     ...     ...   ...      ...      ...     ...         ...
# 886         0       2    male  27.0  13.0000        S  Second        True
# 887         1       1  female  19.0  30.0000        S   First       False
# 888         0       3  female   NaN  23.4500        S   Third       False
# 889         1       1    male  26.0  30.0000        C   First        True
# 890         0       3    male  32.0   7.7500        Q   Third        True
#
#      embark_town alive  alone
# 0    Southampton    no  False
# ...

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %% [markdown]
# ### replace method

# %%
titanic["sex"].replace("female","F")
# Out:
# 0      male
# 1         F
# 2         F
# 3         F
# 4      male
#        ...
# 886    male
# 887       F
# 888       F
# 889    male
# 890    male
# Name: sex, Length: 891, dtype: object

# %%
titanic["sex"].replace(["female","male"],["f","m"])
# Out:
# 0      m
# 1      f
# 2      f
# 3      f
# 4      m
#       ..
# 886    m
# 887    f
# 888    f
# 889    m
# 890    m
# Name: sex, Length: 891, dtype: object

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
titanic["sex"].replace(["female","male"],["f","m"],inplace=True)

# %%
titanic
# Out:
#      survived  pclass sex   age  sibsp  parch     fare embarked   class
# 0           0       3   m  22.0      1      0   7.2500        S   Third  \
# 1           1       1   f  38.0      1      0  71.2833        C   First
# 2           1       3   f  26.0      0      0   7.9250        S   Third
# 3           1       1   f  35.0      1      0  53.1000        S   First
# 4           0       3   m  35.0      0      0   8.0500        S   Third
# ..        ...     ...  ..   ...    ...    ...      ...      ...     ...
# 886         0       2   m  27.0      0      0  13.0000        S  Second
# 887         1       1   f  19.0      0      0  30.0000        S   First
# 888         0       3   f   NaN      1      2  23.4500        S   Third
# 889         1       1   m  26.0      0      0  30.0000        C   First
# 890         0       3   m  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 0      man        True  Southampton    no  False
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
print(): Prints output to the console.
input(): Reads input from the user via the console.
len(): Returns the length of an object, such as a string, list, or tuple.
range(): Generates a sequence of numbers within a specified range.
type(): Returns the type of an object.
int(), float(), str(): Convert values to integers, floats, or strings, respectively.
list(), tuple(), set(), dict(): Convert data into lists, tuples, sets, or dictionaries, respectively.
max(), min(): Returns the maximum or minimum value from a sequence or a set of arguments.
sum(): Calculates the sum of elements in a sequence.
sorted(): Returns a new sorted list from the elements of an iterable.
enumerate(): Generates an index and value pair for each element in an iterable.
zip(): Combines multiple iterables into a single iterable of tuples.
open(): Opens a file for reading, writing, or appending.
str.split(): Splits a string into a list of substrings based on a delimiter.
str.join(): Joins a sequence of strings into a single string using a specified delimiter.
str.strip(): Removes leading and trailing whitespace from a string.
str.replace(): Replaces occurrences of a substring with another substring in a string.
os.path.join(): Joins multiple path components into a single path.
os.listdir(): Returns a list of files and directories in a given directory.
random.randint(): Generates a random integer within a specified range.

# %%
import pandas as pd
import seaborn as sb

# %%
sb.get_data_home()
# Out:
# 'C:\\Users\\jbt\\AppData\\Local\\seaborn\\seaborn\\Cache'

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sb.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df.drop_duplicates("day")
# Out:
#     total_bill   tip     sex smoker   day    time  size
# 0        16.99  1.01  Female     No   Sun  Dinner     2
# 19       20.65  3.35    Male     No   Sat  Dinner     3
# 77       27.20  4.00    Male     No  Thur   Lunch     4
# 90       28.97  3.00    Male    Yes   Fri  Dinner     2

# %%
df["day"].replace(['Thur', 'Fri', 'Sat', 'Sun'],['Thursday','Friday','Saturday','Sunday'],inplace=True)

# %%
df
# Out:
#      total_bill   tip     sex smoker       day    time  size
# 0         16.99  1.01  Female     No    Sunday  Dinner     2
# 1         10.34  1.66    Male     No    Sunday  Dinner     3
# 2         21.01  3.50    Male     No    Sunday  Dinner     3
# 3         23.68  3.31    Male     No    Sunday  Dinner     2
# 4         24.59  3.61  Female     No    Sunday  Dinner     4
# ..          ...   ...     ...    ...       ...     ...   ...
# 239       29.03  5.92    Male     No  Saturday  Dinner     3
# 240       27.18  2.00  Female    Yes  Saturday  Dinner     2
# 241       22.67  2.00    Male    Yes  Saturday  Dinner     2
# 242       17.82  1.75    Male     No  Saturday  Dinner     2
# 243       18.78  3.00  Female     No  Thursday  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['day'].replace({'Thur': 'Thursday', 'Fri': 'Friday', 'Sat': 'Saturday', 'Sun': 'Sunday'}, inplace=True)
