# %%
import pandas as pd

# %%
products = pd.read_csv('data/Products.csv')
cat = pd.read_csv('data/Categories.csv')

# %%
products
# Out:
#     ProductID                      ProductName  UnitPrice  CategoryID
# 0           1                             Chai      18.00           1  \
# 1           2                            Chang      19.00           1
# 2           3                    Aniseed Syrup      10.00           2
# 3           4     Chef Anton's Cajun Seasoning      22.00           2
# 4           5           Chef Anton's Gumbo Mix      21.35           2
# ..        ...                              ...        ...         ...
# 72         73                       Rad Kaviar      15.00           8
# 73         74                    Longlife Tofu      10.00           7
# 74         75             Rhanbrau Klosterbier       7.75           1
# 75         76                     Lakkalikaari      18.00           1
# 76         77  Original Frankfurter grane Soae      13.00           2
#
#           Date      Date1
# 0   22/11/2024  5/31/2023
# 1   23/11/2024   6/1/2023
# 2   24/11/2024   6/2/2023
# ...

# %%
cat
# Out:
#    CategoryID          CategoryName
# 0           1             Beverages  \
# 1           2            Condiments
# 2           3           Confections
# 3           4        Dairy Products
# 4           5        Grains/Cereals
# 5           6          Meat/Poultry
# 6           7               Produce
# 7           8               Seafood
# 8           9  Fruit and vegetables
#
#                                          Description
# 0        Soft drinks, coffees, teas, beers, and ales
# 1  Sweet and savory sauces, relishes, spreads, an...
# 2                Desserts, candies, and sweet breads
# 3                                            Cheeses
# 4                Breads, crackers, pasta, and cereal
# 5                                     Prepared meats
# 6                          Dried fruit and bean curd
# 7                                   Seaweed and fish
# 8                                                NaN

# %%
products.merge(cat)
# Out:
#     ProductID                    ProductName  UnitPrice  CategoryID
# 0           1                           Chai      18.00           1  \
# 1           2                          Chang      19.00           1
# 2          24             Guarana Fantastica       4.50           1
# 3          34                  Sasquatch Ale      14.00           1
# 4          35                 Steeleye Stout      18.00           1
# ..        ...                            ...        ...         ...
# 72         42  Singaporean Hokkien Fried Mee      14.00           5
# 73         52                       Filo Mix       7.00           5
# 74         56         Gnocchi di nonna Alice      38.00           5
# 75         57                 Ravioli Angelo      19.50           5
# 76         64      Wimmers gute Semmelknadel      33.25           5
#
#           Date      Date1    CategoryName
# 0   22/11/2024  5/31/2023       Beverages  \
# 1   23/11/2024   6/1/2023       Beverages
# ...

# %%
cat.merge(products)
# Out:
#     CategoryID CategoryName                                  Description
# 0            1    Beverages  Soft drinks, coffees, teas, beers, and ales  \
# 1            1    Beverages  Soft drinks, coffees, teas, beers, and ales
# 2            1    Beverages  Soft drinks, coffees, teas, beers, and ales
# 3            1    Beverages  Soft drinks, coffees, teas, beers, and ales
# 4            1    Beverages  Soft drinks, coffees, teas, beers, and ales
# ..         ...          ...                                          ...
# 72           8      Seafood                             Seaweed and fish
# 73           8      Seafood                             Seaweed and fish
# 74           8      Seafood                             Seaweed and fish
# 75           8      Seafood                             Seaweed and fish
# 76           8      Seafood                             Seaweed and fish
#
#     ProductID                      ProductName  UnitPrice        Date
# ...

# %%
dep=pd.DataFrame({"depid":[10,20,30],
                   "depname":['IT','HR','DBA']})

# %%
dep
# Out:
#    depid depname
# 0     10      IT
# 1     20      HR
# 2     30     DBA

# %%
emp=pd.DataFrame({"empid":[1,2,3,4],
                   "empname":['Shimi','Moshe','Noa','Avi'],
                   "depid":[10,10,20,0]})

# %%
emp
# Out:
#    empid empname  depid
# 0      1   Shimi     10
# 1      2   Moshe     10
# 2      3     Noa     20
# 3      4     Avi      0

# %%
dep.merge(emp)
# Out:
#    depid depname  empid empname
# 0     10      IT      1   Shimi
# 1     10      IT      2   Moshe
# 2     20      HR      3     Noa

# %%
emp.merge(dep)
# Out:
#    empid empname  depid depname
# 0      1   Shimi     10      IT
# 1      2   Moshe     10      IT
# 2      3     Noa     20      HR

# %%
emp=pd.DataFrame({"empid":[1,2,3,4],
                   "empname":['Shimi','Moshe','Noa','Avi'],
                   "deptid":[10,10,20,0]})

# %%
emp
# Out:
#    empid empname  deptid
# 0      1   Shimi      10
# 1      2   Moshe      10
# 2      3     Noa      20
# 3      4     Avi       0

# %%
dep
# Out:
#    depid depname
# 0     10      IT
# 1     20      HR
# 2     30     DBA

# %%
emp.merge(dep,left_on="deptid",right_on="depid")
# Out:
#    empid empname  deptid  depid depname
# 0      1   Shimi      10     10      IT
# 1      2   Moshe      10     10      IT
# 2      3     Noa      20     20      HR

# %%
#The default is inner join, can use how = inner
emp.merge(dep,
          left_on="deptid",
          right_on="depid",
          how="inner")
# Out:
#    empid empname  deptid  depid depname
# 0      1   Shimi      10     10      IT
# 1      2   Moshe      10     10      IT
# 2      3     Noa      20     20      HR

# %%
#left outer join -- all rows from emp
mp.merge(dep,
          left_on="deptid",
          right_on="depid",
          how="left")
# Out:
#    empid empname  deptid  depid depname
# 0      1   Shimi      10   10.0      IT
# 1      2   Moshe      10   10.0      IT
# 2      3     Noa      20   20.0      HR
# 3      4     Avi       0    NaN     NaN

# %%
#right outer join -- all rows from dep
emp.merge(dep,
          left_on="deptid",
          right_on="depid",
          how="right")
# Out:
#    empid empname  deptid  depid depname
# 0    1.0   Shimi    10.0     10      IT
# 1    2.0   Moshe    10.0     10      IT
# 2    3.0     Noa    20.0     20      HR
# 3    NaN     NaN     NaN     30     DBA

# %%
#full outer join - inner+left+right=outer
emp.merge(dep,
          left_on="deptid",
          right_on="depid",
          how="outer")
# Out:
#    empid empname  deptid  depid depname
# 0    1.0   Shimi    10.0   10.0      IT
# 1    2.0   Moshe    10.0   10.0      IT
# 2    3.0     Noa    20.0   20.0      HR
# 3    4.0     Avi     0.0    NaN     NaN
# 4    NaN     NaN     NaN   30.0     DBA

# %%
emp.merge(dep,
          how="cross")
# Out:
#     empid empname  deptid  depid depname
# 0       1   Shimi      10     10      IT
# 1       1   Shimi      10     20      HR
# 2       1   Shimi      10     30     DBA
# 3       2   Moshe      10     10      IT
# 4       2   Moshe      10     20      HR
# 5       2   Moshe      10     30     DBA
# 6       3     Noa      20     10      IT
# 7       3     Noa      20     20      HR
# 8       3     Noa      20     30     DBA
# 9       4     Avi       0     10      IT
# 10      4     Avi       0     20      HR
# 11      4     Avi       0     30     DBA

# %%
mrg = pd.merge(products,
               cat,
               on = 'CategoryID',
              how='inner')

# %%
mrg.head()
# Out:
#    ProductID         ProductName  UnitPrice  CategoryID        Date
# 0          1                Chai       18.0           1  22/11/2024  \
# 1          2               Chang       19.0           1  23/11/2024
# 2         24  Guarana Fantastica        4.5           1  30/05/2023
# 3         34       Sasquatch Ale       14.0           1  28/02/2026
# 4         35      Steeleye Stout       18.0           1  31/03/2026
#
#        Date1 CategoryName                                  Description
# 0  5/31/2023    Beverages  Soft drinks, coffees, teas, beers, and ales
# 1   6/1/2023    Beverages  Soft drinks, coffees, teas, beers, and ales
# 2  6/23/2023    Beverages  Soft drinks, coffees, teas, beers, and ales
# 3   7/3/2023    Beverages  Soft drinks, coffees, teas, beers, and ales
# 4   7/4/2023    Beverages  Soft drinks, coffees, teas, beers, and ales

# %%
mrg[['ProductID','ProductName','CategoryID','CategoryName']].head()

# %%
mrg.count()

# %%
mrg = pd.merge(products,
               cat,
               on = 'CategoryID')

# %%
mrg.head()
# Out:
#    ProductID         ProductName  UnitPrice  CategoryID        Date
# 0          1                Chai       18.0           1  22/11/2024  \
# 1          2               Chang       19.0           1  23/11/2024
# 2         24  Guarana Fantastica        4.5           1  30/05/2023
# 3         34       Sasquatch Ale       14.0           1  28/02/2026
# 4         35      Steeleye Stout       18.0           1  31/03/2026
#
#        Date1 CategoryName                                  Description
# 0  5/31/2023    Beverages  Soft drinks, coffees, teas, beers, and ales
# 1   6/1/2023    Beverages  Soft drinks, coffees, teas, beers, and ales
# 2  6/23/2023    Beverages  Soft drinks, coffees, teas, beers, and ales
# 3   7/3/2023    Beverages  Soft drinks, coffees, teas, beers, and ales
# 4   7/4/2023    Beverages  Soft drinks, coffees, teas, beers, and ales

# %%
mrg.count()
# Out:
# ProductID       77
# ProductName     77
# UnitPrice       77
# CategoryID      77
# Date            77
# Date1           77
# CategoryName    77
# Description     77
# dtype: int64

# %%
mrg = pd.merge(products,
               cat,
               on = 'CategoryID',
              how='left')

# %%
mrg.count()
# Out:
# ProductID       77
# ProductName     77
# UnitPrice       77
# CategoryID      77
# Date            77
# Date1           77
# CategoryName    77
# Description     77
# dtype: int64

# %%
mrg.head(70)

# %%
mrg = pd.merge(products,
               cat,
               on = 'CategoryID',
              how='right')

# %%
mrg.count()
# Out:
# ProductID       77
# ProductName     77
# UnitPrice       77
# CategoryID      78
# Date            77
# Date1           77
# CategoryName    78
# Description     77
# dtype: int64

# %%
mrg.head(80)
# Out:
#     ProductID             ProductName  UnitPrice  CategoryID        Date
# 0         1.0                    Chai      18.00           1  22/11/2024  \
# 1         2.0                   Chang      19.00           1  23/11/2024
# 2        24.0      Guarana Fantastica       4.50           1  30/05/2023
# 3        34.0           Sasquatch Ale      14.00           1  28/02/2026
# 4        35.0          Steeleye Stout      18.00           1  31/03/2026
# ..        ...                     ...        ...         ...         ...
# 73       45.0             Rogede sild       9.50           8  31/01/2027
# 74       46.0               Spegesild      12.00           8  28/02/2027
# 75       58.0  Escargots de Bourgogne      13.25           8  29/09/2028
# 76       73.0              Rad Kaviar      15.00           8  31/05/2029
# 77        NaN                     NaN        NaN           9         NaN
#
#         Date1          CategoryName
# 0   5/31/2023             Beverages  \
# ...

# %%
#outer -- full join
mrg = pd.merge(products,
               cat,
               on = 'CategoryID',
              how='outer')

# %%
mrg.count()
# Out:
# ProductID       77
# ProductName     77
# UnitPrice       77
# CategoryID      78
# Date            77
# Date1           77
# CategoryName    78
# Description     77
# dtype: int64

# %%
mrg.head(80)

# %%
mask = mrg['CategoryID'].isnull()

# %%
mrg[mask].head()
# Out:
# Empty DataFrame
# Columns: [ProductID, ProductName, UnitPrice, CategoryID, Date, Date1, CategoryName, Description]
# Index: []

# %%
mask = mrg['ProductID'].isnull()

# %%
mrg[mask].head()
# Out:
#     ProductID ProductName  UnitPrice  CategoryID Date Date1
# 77        NaN         NaN        NaN           9  NaN   NaN  \
#
#             CategoryName Description
# 77  Fruit and vegetables         NaN

# %%
dep=pd.DataFrame({"depid":[10,20,30],
                   "name":['IT','HR','DBA']})

# %%
emp=pd.DataFrame({"empid":[1,2,3,4],
                   "name":['Shimi','Moshe','Noa','Avi'],
                   "depid":[10,10,20,0]})

# %%
emp.merge(dep)
# Out:
# Empty DataFrame
# Columns: [empid, name, depid]
# Index: []

# %%
emp.merge(dep,
         on="depid")
# Out:
#    empid name_x  depid name_y
# 0      1  Shimi     10     IT
# 1      2  Moshe     10     IT
# 2      3    Noa     20     HR
